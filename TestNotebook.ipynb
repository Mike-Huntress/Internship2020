# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
from pydatastream import Datastream
from DataIO.DataLib import datastream, DataLib, DatastreamPulls
from DataIO.MetaDataFile import CountryMetaDataFile

CountryMetaDataFile().readMetadata()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DatastreamCode</th>
#       <th>DatastreamCurrency</th>
#       <th>Name</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>USA</th>
#       <td>US</td>
#       <td>USD</td>
#       <td>United States</td>
#     </tr>
#     <tr>
#       <th>JPN</th>
#       <td>JP</td>
#       <td>JAP</td>
#       <td>Japan</td>
#     </tr>
#     <tr>
#       <th>GBR</th>
#       <td>UK</td>
#       <td>UKP</td>
#       <td>Great Britain</td>
#     </tr>
#     <tr>
#       <th>CAN</th>
#       <td>CN</td>
#       <td>CAD</td>
#       <td>Canada</td>
#     </tr>
#     <tr>
#       <th>AUS</th>
#       <td>AU</td>
#       <td>AUD</td>
#       <td>Australia</td>
#     </tr>
#     <tr>
#       <th>SWE</th>
#       <td>SD</td>
#       <td>SWF</td>
#       <td>Sweden</td>
#     </tr>
#     <tr>
#       <th>NOR</th>
#       <td>NW</td>
#       <td>NOR</td>
#       <td>Norway</td>
#     </tr>
#     <tr>
#       <th>ESP</th>
#       <td>ES</td>
#       <td>ESP</td>
#       <td>Spain</td>
#     </tr>
#     <tr>
#       <th>ITA</th>
#       <td>IT</td>
#       <td>ITL</td>
#       <td>Italy</td>
#     </tr>
#     <tr>
#       <th>DEU</th>
#       <td>BD</td>
#       <td>WGM</td>
#       <td>Germany</td>
#     </tr>
#     <tr>
#       <th>FRA</th>
#       <td>FR</td>
#       <td>FRF</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>CHE</th>
#       <td>SW</td>
#       <td>CHF</td>
#       <td>Switzerland</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dl = DataLib("TestData")
dt = dl.pull("Long_Rate")
cht = dt.plot()
plt.show()
