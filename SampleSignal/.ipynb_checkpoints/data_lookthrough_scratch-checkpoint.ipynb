# %%
# If the below code doesn't work uncomment this and run (this adds the parent directory to the path)
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
import matplotlib.pyplot as plt
from BasicSetupUtilities.MetaDataBuilder import CountryMetaDataFile
from DataIOUtilities.DataLib import DataLib, DatastreamPulls
import pandas as pd

# %%
countryList = ['USA', 'AUS', 'JPN', 'CAN', 'CHE', 'GBR', 'ESP', 'FRA', 'ITA', 'DEU']
countries = CountryMetaDataFile().readMetadata().loc[countryList]
start_date = '1980-01'


##Bespoke code name dictionaries
MSCIEquityDictionary = {
                        'US':'MSUSAML',
                        'AU':'MSAUSTL',
                        'JP':'MSJPANL',
                        'CN':'MSCNDAL',
                        'SW':'MSSWITL',
                        'UK':'MSUTDKL',
                        'ES':'MSSPANL',
                        'FR':'MSFRNCL',
                        'IT':'MSITALL',
                        'BD':'MSGERML'
}

dl = DataLib("SignalData")
dsPuller = DatastreamPulls(countries)

# %%
bondReturnIdx_locFX = dsPuller.ds_country_pull(lambda x: f'BM{x}10Y', start_date, 'RI', 'D')
bondReturnIdx_locFX
# Out:
# country          AUS      DEU      CAN       ESP      FRA       ITA      JPN  \
# date
# 1980-01-01       NaN   49.321      NaN       NaN      NaN       NaN      NaN
# 1980-01-02       NaN   49.330      NaN       NaN      NaN       NaN      NaN
# 1980-01-03       NaN   49.163      NaN       NaN      NaN       NaN      NaN
# 1980-01-04       NaN   49.116      NaN       NaN      NaN       NaN      NaN
# 1980-01-07       NaN   49.125      NaN       NaN      NaN       NaN      NaN
# 1980-01-08       NaN   49.051      NaN       NaN      NaN       NaN      NaN
# 1980-01-09       NaN   48.784      NaN       NaN      NaN       NaN      NaN
# 1980-01-10       NaN   48.507      NaN       NaN      NaN       NaN      NaN
# 1980-01-11       NaN   48.515      NaN       NaN      NaN       NaN      NaN
# 1980-01-14       NaN   48.524      NaN       NaN      NaN       NaN      NaN
# 1980-01-15       NaN   48.533      NaN       NaN      NaN       NaN      NaN
# 1980-01-16       NaN   48.487      NaN       NaN      NaN       NaN      NaN
# 1980-01-17       NaN   48.403      NaN       NaN      NaN       NaN      NaN
# 1980-01-18       NaN   48.411      NaN       NaN      NaN       NaN      NaN
# 1980-01-21       NaN   48.531      NaN       NaN      NaN       NaN      NaN
# 1980-01-22       NaN   48.540      NaN       NaN      NaN       NaN      NaN
# 1980-01-23       NaN   48.631      NaN       NaN      NaN       NaN      NaN
# 1980-01-24       NaN   48.851      NaN       NaN      NaN       NaN      NaN
# 1980-01-25       NaN   48.749      NaN       NaN      NaN       NaN      NaN
# 1980-01-28       NaN   48.758      NaN       NaN      NaN       NaN      NaN
# 1980-01-29       NaN   48.758      NaN       NaN      NaN       NaN      NaN
# 1980-01-30       NaN   48.767      NaN       NaN      NaN       NaN      NaN
# 1980-01-31       NaN   48.710      NaN       NaN      NaN       NaN      NaN
# 1980-02-01       NaN   48.664      NaN       NaN      NaN       NaN      NaN
# 1980-02-04       NaN   48.673      NaN       NaN      NaN       NaN      NaN
# 1980-02-05       NaN   48.682      NaN       NaN      NaN       NaN      NaN
# 1980-02-06       NaN   48.690      NaN       NaN      NaN       NaN      NaN
# 1980-02-07       NaN   48.717      NaN       NaN      NaN       NaN      NaN
# 1980-02-08       NaN   48.726      NaN       NaN      NaN       NaN      NaN
# 1980-02-11       NaN   48.734      NaN       NaN      NaN       NaN      NaN
# ...              ...      ...      ...       ...      
# 1980-01-04      NaN    26.123   36.859
# 1980-01-07      NaN    26.268   36.926
# 1980-01-08      NaN    26.345   37.061
# 1980-01-09      NaN    26.321   37.061
# 1980-01-10      NaN    26.654   37.217
# 1980-01-11      NaN    26.798   36.878
# 1980-01-14      NaN    27.206   36.843
# 1980-01-15      NaN    27.180   36.966
# 1980-01-16      NaN    27.479   36.976
# 1980-01-17      NaN    27.402   36.864
# 1980-01-18      NaN    27.629   36.647
# 1980-01-21      NaN    27.928   36.377
# 1980-01-22      NaN    27.685   36.613
# 1980-01-23      NaN    27.948   36.690
# 1980-01-24      NaN    27.582   36.295
# 1980-01-25      NaN    27.412   36.136
# 1980-01-28      NaN    27.422   36.035
# 1980-01-29      NaN    27.540   35.932
# 1980-01-30      NaN    27.479   36.032
# 1980-01-31      NaN    27.401   36.112
# 1980-02-01      NaN    27.122   35.815
# 1980-02-04      NaN    26.952   35.590
# 1980-02-05      NaN    26.818   34.948
# 1980-02-06      NaN    26.864   34.585
# 1980-02-07      NaN    27.112   35.014
# 1980-02-08      NaN    27.375   34.887
# 1980-02-11      NaN    27.277   34.470
# ...             ...       ...      ...
# 2020-06-24  396.620  1061.882  726.716
# 2020-06-25  398.491  1065.849  727.412
# 2020-06-26  398.568  1064.213  729.959
# 2020-06-29  398.464  1065.588  730.085
# 2020-06-30  398.578  1065.084  728.956
# 2020-07-01  397.199  1061.718  726.915
# 2020-07-02  397.688  1063.837  727.726
# 2020-07-03  396.746  1063.383  727.762
# 2020-07-06  396.532  1062.413  726.861
# 2020-07-07  395.846  1063.748  729.384
# 2020-07-08  397.379  1064.229  727.572
# 2020-07-09  399.287  1066.725  730.886
# 2020-07-10  400.348  1067.465  728.987
# 2020-07-13  397.768  1063.661  730.709
# 2020-07-14  398.391  1067.461  732.548
# 2020-07-15  398.615  1065.974  731.418
# 2020-07-16  399.503  1068.768  732.686
# 2020-07-17  397.761  1066.416  731.581
# 2020-07-20  397.365  1067.950  732.164
# 2020-07-21  399.227  1069.177  733.090
# 2020-07-22  399.741  1070.483  733.902
# 2020-07-23  400.775  1070.305  734.827
# 2020-07-24  400.125  1068.241  734.407
# 2020-07-27  401.586  1071.038  733.048
# 2020-07-28  402.646  1071.062  735.002
# 2020-07-29  401.559  1069.524  735.014
# 2020-07-30  402.988  1072.101  737.767
# 2020-07-31  402.702  1070.613  738.148
# 2020-08-03  402.343  1070.725  736.332
# 2020-08-04  401.110  1073.065  739.770
#
# [10591 rows x 10 columns]

# %%
bondReturnIdx_locFX.plot()
plt.show()

# %%
newdf = bondReturnIdx_locFX.rolling(365*3, min_periods=100).apply(lambda x: x.iloc[-1] - x.iloc[0], raw=False)
newdf.tail()

newdf.plot()

# %%
fxVsUSD = dsPuller.ds_country_pull(lambda x: f'{x}XRUSD.', start_date, '', 'M')

# %%
fxVsUSD.drop(["ITA", "ESP", "JPN", "FRA"], axis=1)
# Out:
# country     AUS     DEU     CAN     CHE     GBR     USA
# 2019-01  1.3982  1.7132  1.3301  0.9892  1.2901  1.1454
# 2019-02  1.4006  1.7230  1.3206  1.0015  1.3017  1.1379
# 2019-03  1.4121  1.7304  1.3368  1.0006  1.3165  1.1228
# 2019-04  1.4066  1.7403  1.3378  1.0065  1.3036  1.1201
# 2019-05  1.4403  1.7487  1.3459  1.0108  1.2841  1.1149
# 2019-06  1.4395  1.7318  1.3287  0.9889  1.2679  1.1374
# 2019-07  1.4326  1.7434  1.3101  0.9874  1.2469  1.1130
# 2019-08  1.4762  1.7579  1.3277  0.9789  1.2155  1.0989
# 2019-09  1.4683  1.7774  1.3241  0.9905  1.2354  1.0905
# 2019-10  1.4717  1.7696  1.3190  0.9936  1.2647  1.1155
# 2019-11  1.4651  1.7698  1.3239  0.9931  1.2883  1.1019
# 2019-12  1.4528  1.7599  1.3172  0.9836  1.3101  1.1227
# 2020-01  1.4595  1.7620  1.3087  0.9702  1.3071  1.1082
# 2020-02  1.5001  1.7935  1.3286  0.9761  1.2957  1.1001
# 2020-03  1.6124  1.7678  1.3953  0.9570  1.2364  1.1016
# 2020-04  1.5862  1.8006  1.4058  0.9710  1.2410  1.0934
# 2020-05  1.5353  1.7940  1.3970  0.9707  1.2300  1.1107
# 2020-06  1.4494  1.7378  1.3550  0.9511  1.2526  1.1237
# 2020-07  1.4213  1.7062     NaN  0.9346  1.2691  1.1635
# 2020-08     NaN     NaN     NaN     NaN     NaN     NaN
#
# [488 rows x 6 columns]

# %%
def firstvalid(x):
    return x[x.first_valid_index()]

a = bondReturnIdx_locFX.copy()
initial_prices = a.apply(firstvalid, axis=0)
initial_prices
# Out:
# country
# AUS     75.098
# DEU     49.321
# CAN     65.345
# ESP    100.000
# FRA     59.477
# ITA    100.000
# JPN     67.959
# CHE     63.780
# GBR     26.143
# USA     37.527
# dtype: float64

# %%
#hedged returns (in each country's currency):
#bondReturnIdx_locFX.plot()

hedgedreturns = bondReturnIdx_locFX / initial_prices
hedgedreturns.plot()
plt.show()

#hedged returns (in dollars):
b = fxVsUSD.copy()
b.loc[:, 'USA'] = 1
initial_exchange_rates = b.apply(firstvalid, axis=0)
#initial_exchange_rates
ey = bondReturnIdx_locFX.resample('M').last()
bond_unhedged_returns =  ey * fxVsUSD / initial_exchange_rates/ initial_prices
bond_unhedged_returns.plot()

a = fxVsUSD.drop(['ITA', "JPN", "ESP", "FRA"], axis=1)
a.plot()

# %%
#hedged returns (in each country's currency):
#bondReturnIdx_locFX.plot()

hedgedreturns = bondReturnIdx_locFX.loc[:,"GBR"]  / initial_prices.loc["GBR"]
hedgedreturns.plot()


#hedged returns (in dollars):
b = fxVsUSD.copy()
b.loc[:, 'USA'] = 1
initial_exchange_rates = b.apply(firstvalid, axis=0).loc["GBR"]
#initial_exchange_rates
ey = bondReturnIdx_locFX.resample('M').last().loc[:, "GBR"]
bond_unhedged_returns =  ey * fxVsUSD.loc[:,"GBR"] / initial_exchange_rates / initial_prices.loc["GBR"]
bond_unhedged_returns.plot()

plt.show()

a = fxVsUSD.loc[:,"GBR"]
a.plot()

# %%
#sharpe stuff
#calculate average annual return and volatility of 60/40 portfolio
equities = dsPuller.ds_country_pull(lambda x: MSCIEquityDictionary[x], start_date, 'MSPI', 'Y')
bonds = dsPuller.ds_country_pull(lambda x: f'BM{x}10Y', start_date, 'RI', 'Y')
equities_annual_return = equities.pct_change(1)
bonds_annual_return = bonds.pct_change(1)
# Out:
# country       AUS       DEU       CAN       ESP       FRA       ITA       JPN  \
# date
# 1980          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1981          NaN  0.006529       NaN       NaN       NaN       NaN       NaN
# 1982          NaN  0.051991       NaN       NaN       NaN       NaN       NaN
# 1983          NaN  0.216376       NaN       NaN       NaN       NaN       NaN
# 1984          NaN  0.018513       NaN       NaN       NaN       NaN       NaN
# 1985          NaN  0.160680       NaN       NaN       NaN       NaN  0.129993
# 1986          NaN  0.126997  0.219655       NaN       NaN       NaN  0.118567
# 1987          NaN  0.090780  0.132244       NaN  0.174811       NaN  0.060885
# 1988          NaN  0.031165  0.011089       NaN  0.046211       NaN  0.046233
# 1989     0.118826  0.046968  0.096584       NaN  0.168726       NaN  0.048783
# 1990     0.134747  0.016646  0.138425       NaN  0.044019       NaN -0.008499
# 1991     0.180643 -0.027930  0.055706       NaN  0.052567       NaN -0.017396
# 1992     0.299285  0.145645  0.230679  0.269302  0.183135       NaN  0.161077
# 1993     0.131417  0.137675  0.086070  0.035343  0.117611  0.090222  0.115625
# 1994     0.252812  0.179976  0.170079  0.435212  0.255053  0.401896  0.149674
# 1995    -0.124409 -0.063845 -0.090476 -0.128688 -0.105657 -0.112755 -0.062238
# 1996     0.234327  0.183201  0.232244  0.251065  0.200179  0.219861  0.157730
# 1997     0.150779  0.077444  0.135108  0.290930  0.122546  0.315282  0.071723
# 1998     0.173692  0.096311  0.125382  0.169048  0.103174  0.194007  0.107791
# 1999     0.135664  0.161042  0.111390  0.176902  0.165679  0.176842  0.024701
# 2000    -0.068941 -0.073979 -0.043371 -0.070469 -0.083284 -0.073392  0.045107
# 2001     0.172923  0.093160  0.125113  0.093435  0.083544  0.084460  0.014773
# 2002     0.017682  0.045472  0.060925  0.058284  0.052119  0.065194  0.055407
# 2003     0.128058  0.106140  0.103624  0.122976  0.125169  0.116911  0.067793
# 2004     0.022526  0.038953  0.064004  0.050262  0.045834  0.047205 -0.027049
# 2005     0.082353  0.104013  0.080804  0.106491  0.104658  0.108899  0.017643
# 2006     0.063576  0.064231  0.074078  0.063466  0.065151  0.058308  0.019996
# 2007     0.009241 -0.013396  0.035948 -0.013508 -0.013633 -0.004570  0.004500
# 2008     0.027807  0.016445  0.052191  0.010358  0.010558  0.018549  0.038795
# 2009     0.275513  0.162952  0.154310  0.097306  0.134649  0.074775  0.054803
# 2010    -0.075578  0.004535 -0.028175  0.050102  0.028390  0.094482  0.009677
# ITA    0.429731
# JPN    0.346434
# USA    0.887590
# dtype: float64

# %%
global_bonds = bonds.mean(axis=1)
global_bond_returns = global_bonds.pct_change(1)
global_bond_returns
old_sixty_forty = .8*sixty_forty
new_global_bonds = .2*global_bond_returns
new_portfolio = old_sixty_forty.add(new_global_bonds, axis=0)
new_portfolio
new_mean = new_portfolio.mean()
new_std = new_portfolio.std()
new_sharpe = new_mean / new_std
new_sharpe
# Out:
# country
# AUS    0.907353
# CAN    0.959342
# CHE    0.671336
# DEU    0.668106
# ESP    0.607231
# FRA    0.677644
# GBR    0.952598
# ITA    0.520755
# JPN    0.485158
# USA    1.006417
# dtype: float64

# %%
gdpdata = dl.pull("CurrAcctPctGDP")
#gdpdata.plot()
gdpdata.loc[:,["USA", "ESP", "GBR", "AUS", "FRA", "ITA"]].plot()

# %%
LongRates = dl.pull('LongRates')
ShortRates = dl.pull('ShortRates')

#print(LongRates["USA"])
#print(LongRates.loc[:,"USA"])

for country in gdpdata.columns:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(LongRates[country].to_timestamp(), label="long")
    ax1.plot(ShortRates[country].to_timestamp(), label="short")
    ax1.plot(gdpdata[country].to_timestamp(), label="curr_act_gdp", color="black")
    ax1.legend()
    ax2.plot(fxVsUSD.loc[:,country].to_timestamp(), label="fx", color="red")
    ax2.legend()
    plt.title(country)
    plt.show()

# %%
growth = dl.pull('GDP/Nominal')
growth2 = dl.pull('GDP/Real')
bonds = bondReturnIdx_locFX

growth_proxy = growth.rolling(4*5, min_periods=1).mean()
growth2_proxy = growth2.rolling(4*5).mean()

#print(LongRates["USA"])
#print(LongRates.loc[:,"USA"])

for country in gdpdata.columns:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1.plot(growth_proxy[country].to_timestamp(), label="growth", color="green")
    #ax1.plot(growth2_proxy[country].to_timestamp(), label="growth2", color="black")
    ax1.legend()
    ax2.plot(bonds[country].to_timestamp(), label="bond returns", color="red")
    #ax2.plot(LongRates[country].to_timestamp())
    ax2.legend()
    plt.title(country)
    plt.show()

# %%
dl.write_data("BondRetIdx/LocalFX",bondReturnIdx_locFX.to_timestamp())
test = dl.pull("BondRetIdx/LocalFX")
test.head()data:image/png;base64,...
# Out:
# country     AUS     DEU  CAN  ESP  FRA  ITA  JPN  CHE     GBR     USA
# date
# 1980-01-01  NaN  49.321  NaN  NaN  NaN  NaN  NaN  NaN  26.143  37.527
# 1980-01-02  NaN  49.330  NaN  NaN  NaN  NaN  NaN  NaN  25.882  37.156
# 1980-01-03  NaN  49.163  NaN  NaN  NaN  NaN  NaN  NaN  25.911  36.941
# 1980-01-04  NaN  49.116  NaN  NaN  NaN  NaN  NaN  NaN  26.123  36.859
# 1980-01-07  NaN  49.125  NaN  NaN  NaN  NaN  NaN  NaN  26.268  36.926

# %%
longRates = dsPuller.ds_country_pull(lambda x: f'TR{x}10T', start_date, 'RY', 'M')

# %%
longRates.plot()
plt.show()

# %%
dl.write_data("LongRates",longRates.to_timestamp())

# %%
shortRates = dsPuller.ds_country_pull(lambda x: f'TR{x}2YT', start_date, 'RY', 'M')
shortRates.plot()
plt.show()
dl.write_data("ShortRates", shortRates.to_timestamp())

# %%
equityPrices = dsPuller.ds_country_pull(lambda x: MSCIEquityDictionary[x], start_date, 'MSPI', 'D')
equityPrices.plot()
plt.show()
dl.write_data("EquityPrices", equityPrices.to_timestamp())

# %%
M2_usd = dsPuller.ds_country_pull(lambda x: f'{x}CMS2..B', start_date, '', 'M',list(filter(lambda x: x !='AUS', countryList)))
M2_usd.plot()
plt.show()
dl.write_data("M2/inUSD", M2_usd.to_timestamp())



M1_usd = dsPuller.ds_country_pull(lambda x: f'{x}CMS1..B', start_date, '', 'M',['AUS'])
M1_usd.plot()
plt.show()
dl.write_data("M1/inUSD", M1_usd.to_timestamp())

M3_usd = dsPuller.ds_country_pull(lambda x: f'{x}CMS3..B', start_date, '', 'M',['AUS'])
M3_usd.plot()
plt.show()
dl.write_data("M3/inUSD", M3_usd.to_timestamp())

# %%
currentAccountNominal_usd = dsPuller.ds_country_pull(lambda x: f'{x}CCUR..B', start_date, '', 'M')
currentAccountNominal_usd.plot()
plt.show()
dl.write_data("CurrAcctNom/inUSD", currentAccountNominal_usd.to_timestamp())

# %%
currentAccount_pctGDP = dsPuller.ds_country_pull(lambda x: f'{x}CCUR..Q', start_date, '', 'M')
currentAccount_pctGDP.plot()
plt.show()
dl.write_data("CurrAcctPctGDP", currentAccount_pctGDP.to_timestamp())

# %%
gdpNominal_usd = dsPuller.ds_country_pull(lambda x: f'{x}CGDP..A', start_date, '', 'M')
gdpNominal_usd.plot()
plt.show()
dl.write_data("GDP/Nominal", gdpNominal_usd.to_timestamp())

# %%
gdpReal = dsPuller.ds_country_pull(lambda x: f'{x}CGDP..D', start_date, '', 'M')
gdpReal.plot()
plt.show()
dl.write_data("GDP/Real", gdpReal.to_timestamp())

# %%
fxNomPrices_TrdWts = dsPuller.ds_country_pull(lambda x: f'{x}CXTW..F', start_date, '', 'M',['USA', 'AUS', 'JPN', 'CHE', 'GBR'])
fxNomPrices_TrdWts.plot()
plt.show()
dl.write_data("fxTrdWts/Nominal", fxNomPrices_TrdWts.to_timestamp())

# %%
fxRealPrices_TrdWts = dsPuller.ds_country_pull(lambda x: f'{x}CXTR..F', start_date, '', 'M',['USA', 'AUS', 'JPN', 'CHE', 'GBR'])
fxRealPrices_TrdWts.plot()
plt.show()
dl.write_data("fxTrdWts/Real", fxRealPrices_TrdWts.to_timestamp())

# %%
fxVsUSD = dsPuller.ds_country_pull(lambda x: f'{x}XRUSD.', start_date, '', 'M')
fxVsUSD.plot()
plt.show()
dl.write_data("fxVsUSD", fxVsUSD.to_timestamp())

# %%
coreCPI_SA = dsPuller.ds_country_pull(lambda x: f'{x}CCOR..E', start_date, '', 'M')
coreCPI_SA.plot()
plt.show()
dl.write_data("CoreCPI/SA", coreCPI_SA.to_timestamp())
