# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
import matplotlib.pyplot as plt
from BasicSetupUtilities.MetaDataBuilder import CountryMetaDataFile
from DataIOUtilities.DataLib import DataLib, DatastreamPulls
import pandas as pd
import numpy as np
import scipy.stats as stats

dl = DataLib("SignalData")

# %%
LongRates = dl.pull('LongRates')
ShortRates = dl.pull('ShortRates')
BondIndex = dl.pull('BondRetIdx/LocalFX')

WEEKDAYS_IN_YEAR = 261

def BondReturnMethod(country):
    return BondIndex[country].pct_change().rolling(WEEKDAYS_IN_YEAR, min_periods=0).sum()

# Here we calculate the bond premium 
LongMinusShortRates = LongRates - ShortRates
dl.write_data("LongMinusShortRates", LongMinusShortRates)

# Normally we expect greater returns if bond premiums are higher
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1_label = 'Bond Premium'
ax1.plot(LongMinusShortRates['USA'].to_timestamp(), color = 'tab:blue', label = ax1_label)
ax1.set_ylabel(ax1_label)
ax1.legend(loc=2)
ax2_label = 'Bond Returns, Past Quarter'
ax2.plot(BondReturnMethod('USA').to_timestamp(), color = 'tab:red', label = ax2_label)
ax2.set_ylabel(ax2_label)
ax2.legend()
plt.title('GBR Bond Returns vs. Bond Premium')
plt.show()

# %%
# Just looking at data with USA 
BondPremium = LongMinusShortRates['USA'].dropna()
StandardizedBondPremium = stats.zscore(BondPremium)

# %%
# Function that inputs BondPremium percent changes and outputs a standardized and normalized signal 
# for the last day of the percent changes in the datastream. 

def Signal(data, country):
    
    data = data[country].fillna(0)
    rescaled_data = []
    standardized_data = stats.zscore(data)
    minimum = min(standardized_data)
    maximum = max(standardized_data)
    
    for i in range(len(standardized_data)):
        new_x = (2 *(standardized_data[i]-minimum))/(maximum - minimum) - 1
        rescaled_data.append(new_x)
    
    return rescaled_data

# %%
Signal(LongMinusShortRates, 'USA')

# Dataframe work 
df = pd.DataFrame(LongMinusShortRates['USA'])
df['Signal USA'] = Signal(LongMinusShortRates, 'USA')
df
# Out:
#            USA  Signal USA
# date
# 1980-01 -0.900   -0.531828
# 1980-02 -0.750   -0.470226
# 1980-03 -2.040   -1.000000
# 1980-04 -1.900   -0.942505
# 1980-05 -0.130   -0.215606
# 1980-06  0.970    0.236140
# 1980-07  1.120    0.297741
# 1980-08  0.980    0.240246
# 1980-09  0.190   -0.084189
# 1980-10 -0.240   -0.260780
# 1980-11 -0.770   -0.478439
# 1980-12 -1.330   -0.708419
# 1981-01 -0.630   -0.420945
# 1981-02 -0.650   -0.429158
# 1981-03 -0.780   -0.482546
# 1981-04 -0.050   -0.182752
# 1981-05 -0.670   -0.437372
# 1981-06 -1.010   -0.577002
# 1981-07 -0.900   -0.531828
# 1981-08 -1.210   -0.659138
# 1981-09 -1.370   -0.724846
# 1981-10 -0.820   -0.498973
# 1981-11  0.130   -0.108830
# 1981-12  0.660    0.108830
# 1982-01  0.350   -0.018480
# 1982-02 -0.460   -0.351129
# 1982-03 -0.400   -0.326489
# 1982-04 -0.320   -0.293634
# 1982-05 -0.180   -0.236140
# 1982-06  0.010   -0.158111
# ...        ...         ...
# 2018-03  0.596    0.082546
# 2018-04  0.486    0.037372
# ...

# %%
BondReturnMethod('USA').plot()

# %%
# Comparing bond returns and indicator signal in USA

date_time = pd.date_range('1980-01','2020-08', 
              freq='MS').strftime("%Y-%b").tolist()
date_time = pd.to_datetime(date_time)

DF = pd.DataFrame()
DF['signal'] = Signal(LongMinusShortRates, 'USA')
DF = DF.set_index(date_time)

fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.3)
plt.xticks(rotation=90)
plt.plot(BondReturnMethod('USA').resample('M').last().to_timestamp())
plt.axhline(linewidth=1, color='black')
plt.plot(DF)

# %%
# Plot of signal outputs

plt.plot(Signal(LongMinusShortRates, 'USA'))
plt.axhline(linewidth=1, color='black')

# %%
# Plot of cumsum of bond returns and signal indicator for bond premium 
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1_label = 'Bond Returns'
ax1.plot(BondReturnMethod('USA').resample('M').last().cumsum().to_timestamp(), color = 'tab:blue', label = ax1_label)
ax1.set_ylabel(ax1_label)
ax1.legend(loc=2)
ax2_label = 'Bond Premium Signal'
ax2.plot(df.iloc[:, 1].to_timestamp(), color = 'tab:red', label = ax2_label)
ax2.set_ylabel(ax2_label)
ax2.axhline(linewidth=1, color='black')
ax2.legend()
plt.title('USA Bond Returns vs. Bond Premium Signal')
plt.show()

# %% [markdown]
# # Thoughts for calculating P&L
#
# Ok so we want to look a bit in the future --> some sort of lag when calculating. To start with I'll do a lag of a quarter (3 months).
#
# Aka if now our signal says -1 we want to sell 100% of our bonds.

# %%
# PnL if following signal 

BondReturnsUpsampled = BondReturnMethod('USA').resample('M').last()
BondIndexUpsampled = BondIndex['USA'].resample('M').last().diff().fillna(0)
SignalBondPremium = df.iloc[:, 1]

PnL = 0
PnL_plot = []

for i in range(len(df)):
    PnL += BondIndexUpsampled[i] * SignalBondPremium[i]

    PnL_plot.append(PnL)

print(PnL)
# Out:
# 138.94169117043134

# %%
# buy and hold seems to perform much better! 

Base_PnL = 0
Base_PnL_plot = []

for i in range(len(df)):
    Base_PnL += BondIndexUpsampled[i]
    Base_PnL_plot.append(Base_PnL)
    
print(Base_PnL)
# Out:
# 516.7719999999999

# %%
plt.plot(PnL_plot) # in blue 
plt.plot(Base_PnL_plot) # in orange

# %%
df_zscore = pd.DataFrame(stats.zscore(LongMinusShortRates.dropna()))
zscore_matrix = df_zscore.to_numpy()

d = []

for i in range(len(zscore_matrix)):
        row = zscore_matrix[i]
        sum_ = np.sum(row).tolist()
        sum_abs = np.sum([abs(number) for number in row])
        new_elements_list = []
        for j in range(10):
            new_element = row[j] - abs(row[j])*(sum_/sum_abs)
            new_elements_list.append(new_element)
        
        d.append(new_elements_list)
        

# in theory can i do 250% or something 
df_added = pd.DataFrame(d)
df_added
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.313140 -0.069721 -0.366481 -0.223789 -0.304721 -0.098469  2.508745
# 1    0.581605 -0.085476 -0.183446 -0.648483 -0.527986  0.313730  2.053936
# 2    0.844531  0.886617 -0.291426 -0.305670 -0.752099 -0.948261  1.712843
# 3    0.576520  0.900962 -0.274173 -0.326271 -0.847350 -0.817984  1.545927
# 4    1.412774  0.831208 -0.108822 -1.044829 -0.672129 -1.200861  1.816824
# 5    1.650625  0.756880  0.011737 -1.086573 -0.432810 -1.365540  1.290322
# 6    1.170367  0.792961  0.003505 -1.501348 -0.020081 -1.726667  1.549308
# 7    0.775496  0.833581 -0.069676 -0.924725  0.112794 -1.302049  1.229385
# 8    0.570287  0.886312  0.038562 -0.989823  0.079364 -1.621864  1.356008
# 9    0.349581  0.810798  0.116121 -1.060313  0.068431 -1.616105  1.398191
# 10   0.255908  0.920249  0.145418 -1.429467  0.017515 -1.462889  1.564757
# 11   0.307464  0.959456  0.246892 -1.459958  0.242071 -1.821848  1.490134
# ...

# %%
df_zscore
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.602353 -0.134115 -0.704960 -0.430478 -0.586158 -0.189414  1.694939
# 1    0.452194 -0.119745 -0.256994 -0.908474 -0.739667  0.243923  1.596922
# 2    0.688929  0.723261 -0.376452 -0.394851 -0.971529 -1.224923  1.397258
# 3    0.581322  0.908467 -0.271926 -0.323597 -0.840407 -0.811282  1.558804
# 4    1.270006  0.747210 -0.122604 -1.177161 -0.757257 -1.352954  1.633224
# 5    1.657391  0.759983  0.011785 -1.082155 -0.431051 -1.359989  1.295611
# 6    1.442177  0.977121  0.004319 -1.263259 -0.016897 -1.452847  1.909124
# 7    1.313049  1.411396 -0.049437 -0.656116  0.190980 -0.923837  2.081561
# 8    0.947186  1.472067  0.064048 -0.708072  0.131815 -1.160203  2.252183
# 9    0.624365  1.448118  0.207397 -0.736277  0.122220 -1.122216  2.497225
# 10   0.430673  1.548704  0.244727 -1.016839  0.029476 -1.040613  2.633359
# 11   0.516758  1.612568  0.414954 -1.039106  0.406851 -1.296676  2.504485
# ...

# %%
def SignalAll(data):
    
    data = data.fillna(0)
    standardized_data = stats.zscore(data)
    
    minimum = [min(idx) for idx in zip(*standardized_data)]
    maximum = [min(idx) for idx in zip(*standardized_data)]
            
    
    return minimum, maximum, standardized_data

# %%
AllMinimum, AllMaximum, StandardizedData = SignalAll(LongMinusShortRates)

# %%
# Dataframe work 
df_Developed = pd.DataFrame(Signal(LongMinusShortRates, 'USA'))
df_Developed['Signal GBR'] = Signal(LongMinusShortRates, 'GBR')
df_Developed['Signal CHE'] = Signal(LongMinusShortRates, 'CHE')
df_Developed['Signal JPN'] = Signal(LongMinusShortRates, 'JPN')
df_Developed['Signal AUS'] = Signal(LongMinusShortRates, 'AUS')
df_Developed['Signal CAN'] = Signal(LongMinusShortRates, 'CAN')
df_Developed['Signal ITA'] = Signal(LongMinusShortRates, 'ITA')
df_Developed['Signal FRA'] = Signal(LongMinusShortRates, 'FRA')
df_Developed['Signal ESP'] = Signal(LongMinusShortRates, 'ESP')
df_Developed['Signal DEU'] = Signal(LongMinusShortRates, 'DEU')
df_Developed
# Out:
#             0  Signal GBR  Signal CHE  Signal JPN  Signal AUS  Signal CAN  \
# 0   -0.531828   -0.448046   -0.973286    0.292922   -0.045455   -0.245867
# 1   -0.470226   -0.448046   -0.973286    0.198104   -0.061983   -0.245867
# 2   -1.000000   -0.448046   -0.973286    0.753471   -0.173554   -0.245867
# 3   -0.942505   -0.448046   -0.973286    0.763630   -0.090909   -0.245867
# 4   -0.215606   -0.448046   -0.973286    0.966813    0.045455   -0.245867
# 5    0.236140   -0.448046   -0.973286   -0.082966    0.008264   -0.245867
# 6    0.297741   -0.448046   -0.973286   -0.177785    0.016529   -0.245867
# 7    0.240246   -0.448046   -0.973286    0.005080    0.090909   -0.245867
# 8   -0.084189   -0.448046   -0.973286    0.147308    0.041322   -0.245867
# 9   -0.260780   -0.448046   -0.973286    0.228581    0.033058   -0.245867
# 10  -0.478439   -0.448046   -0.973286    0.079580    0.033058   -0.245867
# 11  -0.708419   -0.448046   -0.973286    0.438537   -0.090909   -0.245867
# ...
