# %% [markdown]
# # Basic Python Training
# ### Python and pandas is extremely well documented. When in doubt, use Google and find the link corresponding to the API here https://pandas.pydata.org/docs/reference/index.html#api

# %%
# If the below code doesn't work uncomment this and run (this adds the parent directory to the path)
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from pydatastream import Datastream
import matplotlib.pyplot as plt
from BasicSetupUtilities.MetaDataBuilder import CountryMetaDataFile
from DataIOUtilities.DataLib import DataLib, DatastreamPulls
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading and writing/storing data

# %% [markdown]
# ### Set up the data library

# %%
dl = DataLib("SignalData")
hasattr(dl, "date")
# Out:
# False

# %% [markdown]
# ### Pull and look at the data. See SignalDataLibrary.py for the data available to you from Eikon. Use head and tail to look at the top and bottom of the dataframes.

# %%
LongRates = dl.pull('LongRates')
ShortRates = dl.pull('ShortRates')

# %%
LongRates.head()
# Out:
# country   AUS  DEU  CAN  ESP  FRA  ITA   JPN  CHE   GBR   USA
# date
# 1980-01 10.08 7.92  nan  nan  nan  nan  8.64  nan 13.92 10.33
# 1980-02 10.45 8.15  nan  nan  nan  nan  8.50  nan 13.71 11.29
# 1980-03 10.55 8.96  nan  nan  nan  nan  9.32  nan 13.72 12.79
# 1980-04 11.20 9.83  nan  nan  nan  nan 10.00  nan 13.54 12.69
# 1980-05 11.73 8.99  nan  nan  nan  nan 10.30  nan 13.07 10.57

# %%
ShortRates.head()
# Out:
# country    AUS     DEU  CAN  ESP  FRA  ITA    JPN  CHE  GBR    USA
# date
# 1980-01   9.97     NaN  NaN  NaN  NaN  NaN  7.295  NaN  NaN  11.23
# 1980-02  10.38   8.426  NaN  NaN  NaN  NaN  7.295  NaN  NaN  12.04
# 1980-03  10.75   9.123  NaN  NaN  NaN  NaN  7.295  NaN  NaN  14.83
# 1980-04  11.20  10.085  NaN  NaN  NaN  NaN  7.960  NaN  NaN  14.59
# 1980-05  11.40   9.416  NaN  NaN  NaN  NaN  7.960  NaN  NaN  10.70

# %% [markdown]
# ### Generate some new data and store it

# %%
LongMinusShortRates = LongRates - ShortRates
dl.write_data("LongMinusShortRates", LongMinusShortRates)
LongMinusShortRates.tail()
# Out:
# country    AUS    DEU    CAN    ESP    FRA    ITA    JPN    CHE    GBR    USA
# date
# 2020-04  0.472  0.183  0.220  0.845  0.528  1.135  0.141  0.235  0.197  0.401
# 2020-05  0.668  0.173  0.195  0.838  0.501  1.252  0.132  0.108  0.213  0.438
# 2020-06  0.619  0.260  0.250  0.988  0.486  1.126  0.170  0.214  0.233  0.504
# 2020-07  0.660  0.260  0.241  1.000  0.534  1.236  0.186  0.255  0.274  0.518
# 2020-08  0.583  0.177  0.205  0.713  0.415  1.097  0.158  0.260  0.174  0.448

# %%
LongMinusShortRatesFromStorage = dl.pull("LongMinusShortRates")
LongMinusShortRatesFromStorage.tail()
# Out:
# country    AUS    DEU    CAN    ESP    FRA    ITA    JPN    CHE    GBR    USA
# date
# 2020-04  0.472  0.183  0.220  0.845  0.528  1.135  0.141  0.235  0.197  0.401
# 2020-05  0.668  0.173  0.195  0.838  0.501  1.252  0.132  0.108  0.213  0.438
# 2020-06  0.619  0.260  0.250  0.988  0.486  1.126  0.170  0.214  0.233  0.504
# 2020-07  0.660  0.260  0.241  1.000  0.534  1.236  0.186  0.255  0.274  0.518
# 2020-08  0.583  0.177  0.205  0.713  0.415  1.097  0.158  0.260  0.174  0.448

# %% [markdown]
# ## Basic Data Access

# %% [markdown]
# ### Select a subset of columns

# %%
LongRates[['AUS', 'DEU']].tail()
# Out:
# country    AUS    DEU
# date
# 2020-04  0.685 -0.470
# 2020-05  0.893 -0.586
# 2020-06  0.896 -0.393
# 2020-07  0.932 -0.400
# 2020-08  0.866 -0.522

# %% [markdown]
# ### Select a subset of data by index name using loc (see the documentation if you're unfamiliar with the ':' operation for slicing)

# %%
# Select a list of specific rows
LongRates.loc[[pd.Period('2020-03'), pd.Period('2020-04')], ['AUS', 'DEU']]
# Out:
# country    AUS   DEU
# date
# 2020-03  0.786 -0.62
# 2020-04  0.685 -0.47

# %%
# Select a slice of rows
LongRates.loc[pd.Period('2020-02'):pd.Period('2020-09'),['AUS', 'DEU','USA','CHE']]
# Out:
# country    AUS    DEU    USA    CHE
# date
# 2020-02  0.918 -0.436  1.520 -0.769
# 2020-03  0.786 -0.620  1.088 -0.888
# 2020-04  0.685 -0.470  0.635 -0.343
# 2020-05  0.893 -0.586  0.640 -0.541
# 2020-06  0.896 -0.393  0.662 -0.464
# 2020-07  0.932 -0.400  0.682 -0.396
# 2020-08  0.866 -0.522  0.563 -0.533

# %% [markdown]
# ### Select a subset of data by index using iloc

# %%
# Select the last 5 elements
LongRates.iloc[-5:, :]
# Out:
# country    AUS    DEU    CAN    ESP    FRA    ITA    JPN    CHE    GBR    USA
# date
# 2020-04  0.685 -0.470  0.614  0.711  0.013  1.547  0.007 -0.343  0.313  0.635
# 2020-05  0.893 -0.586  0.525  0.731 -0.105  1.777 -0.026 -0.541  0.248  0.640
# 2020-06  0.896 -0.393  0.534  0.584 -0.022  1.469  0.007 -0.464  0.232  0.662
# 2020-07  0.932 -0.400  0.527  0.509 -0.060  1.343  0.048 -0.396  0.212  0.682
# 2020-08  0.866 -0.522  0.468  0.338 -0.203  1.075  0.025 -0.533  0.100  0.563

# %% [markdown]
# ## Plotting the data. For this, look up matplotlib documentation

# %% [markdown]
# ### Plotting all the columns of the dataframe

# %%
BondReturnIndex = dl.pull('BondRetIdx/LocalFX')
BondReturnIndex.plot()
plt.xlabel('Date')
plt.ylabel('Return Index')
plt.title('Bond Return Index By Country')
plt.show()

# %% [markdown]
# ### Plot series from different dataframes

# %%
country = 'USA'
LongRates[country].plot()
ShortRates[country].plot()
LongMinusShortRates[country].plot()
plt.legend(['Long Rate', 'Short Rate', 'Long - Short'])
plt.xlabel('Date')
plt.title(f'{country} Long vs. Short Rate')
plt.show()

# %% [markdown]
# ### Plot multiple charts at the same time. If you want them to all be part of the same figure, check out subplots https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html

# %%
countries = ['USA', 'AUS']
for country in countries:
    LongRates[country].plot()
    ShortRates[country].plot()
    LongMinusShortRates[country].plot()
    plt.legend(['Long Rate', 'Short Rate', 'Long - Short'])
    plt.xlabel('Date')
    plt.title(f'{country} Long vs. Short Rate')
    plt.show()

# %% [markdown]
# ### Plot on separate axes (look up subplots)

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1_label = 'Long Minus Short Rate'
ax1.plot(LongMinusShortRates['USA'].to_timestamp(), label = ax1_label)
ax1.set_ylabel(ax1_label)
ax1.legend()
ax2_label = 'Bond Return Index'
ax2.plot(BondReturnIndex['USA'].to_timestamp(), color = 'tab:red', label = ax2_label)
ax2.set_ylabel(ax2_label)
ax2.legend()
plt.title('Bond Return Index vs. Long Minus Short Rate')
plt.show()

# %% [markdown]
# # Useful Operations. (See the time series section of the API)

# %% [markdown]
# ### Changes (Arithmetic)

# %%
LongRatesMonthlyChange = LongRates.diff()
LongRatesMonthlyChange['USA'].plot()
plt.xlabel("Date")
plt.title("Monthly Change in Long Rate (Arithmetic)")
plt.show()

# %%
WEEKDAYS_IN_YEAR = 261


RGDP = dl.pull('GDP/Real')
RGDPChangeQoQ_Unannualized = RGDP.pct_change(1, fill_method = None).dropna(how='all')
RGDPChangeQoQ = (RGDPChangeQoQ_Unannualized + 1) ** 4 - 1

BondReturnsPastQuarter = BondReturnIndex.pct_change(int(WEEKDAYS_IN_YEAR / 4))

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1_label = 'RGDP Change, QoQ'
ax1.plot(RGDPChangeQoQ['USA'].to_timestamp(), color = 'tab:blue', label = ax1_label)
ax1.set_ylabel(ax1_label)
ax1.legend(loc=2)
ax2_label = 'Bond Return, Past Quarter'
ax2.plot(BondReturnsPastQuarter['USA'].to_timestamp(), color = 'tab:red', label = ax2_label)
ax2.set_ylabel(ax2_label)
ax2.legend()
plt.title('RGDP Change vs. Bond Returns')
plt.show()

# %% [markdown]
# ### Rolling Measures (mean and standard deviation)

# %%
RGDPChangeRollingMean = RGDPChangeQoQ.rolling(40, min_periods=20).mean() # 
RGDPChangeRollingMean.plot()
plt.title('GDP Growth Rolling Mean (20 Year)')
plt.show()
RGDPChangeRollingStdDev = RGDPChangeQoQ.rolling(40, min_periods=20).std()
RGDPChangeRollingStdDev.plot()
plt.title('GDP Growth Rolling Std Dev (20 Year)')
plt.show()

# %% [markdown]
# ### Working with different frequencies

# %% [markdown]
# ### Upsampling

# %%
pd.options.display.float_format = '{:,.2f}'.format
RGDPChange_Upsampled = RGDPChangeQoQ.resample('1B').ffill()
RGDPChange_Upsampled.head()
# Out:
# country     AUS  DEU   CAN  ESP   FRA  ITA   JPN  CHE   GBR   USA
# date
# 1980-04-01 0.01  nan -0.00  nan -0.02  nan -0.03 0.01 -0.08 -0.08
# 1980-04-02 0.01  nan -0.00  nan -0.02  nan -0.03 0.01 -0.08 -0.08
# 1980-04-03 0.01  nan -0.00  nan -0.02  nan -0.03 0.01 -0.08 -0.08
# 1980-04-04 0.01  nan -0.00  nan -0.02  nan -0.03 0.01 -0.08 -0.08
# 1980-04-07 0.01  nan -0.00  nan -0.02  nan -0.03 0.01 -0.08 -0.08

# %% [markdown]
# ### Downsampling

# %%
RGDPChange_Downsampled = RGDPChangeQoQ.resample('1Y').mean()
RGDPChange_Downsampled.head()
# Out:
# country   AUS  DEU   CAN  ESP   FRA  ITA  JPN   CHE   GBR   USA
# date
# 1980     0.03  nan  0.02  nan -0.01  nan 0.05  0.02 -0.04 -0.00
# 1981     0.04  nan  0.02  nan  0.02  nan 0.03  0.01  0.01  0.01
# 1982    -0.02  nan -0.04  nan  0.02  nan 0.04 -0.02  0.02 -0.01
# 1983     0.03  nan  0.06  nan  0.01  nan 0.04  0.02  0.05  0.08
# 1984     0.05  nan  0.06  nan  0.02  nan 0.04  0.04  0.03  0.06

# %% [markdown]
# ### Aggregations across columns

# %%
all_countries = RGDPChangeQoQ.columns
RGDPChangeMeans = RGDPChangeQoQ.copy()
RGDPChangeMeans['Equal Weighted Mean'] = RGDPChangeQoQ.mean(axis=1)
RGDPChangeMeans.tail()
# Out:
# country   AUS   DEU   CAN   ESP   FRA   ITA   JPN   CHE   GBR   USA  \
# date
# 2019Q2   0.02 -0.02  0.03  0.02  0.01  0.00  0.02  0.01 -0.00  0.01
# 2019Q3   0.02  0.01  0.01  0.02  0.01  0.00  0.00  0.02  0.02  0.03
# 2019Q4   0.02 -0.00  0.01  0.02 -0.01 -0.01 -0.07  0.01 -0.00  0.02
# 2020Q1  -0.01 -0.08 -0.08 -0.19 -0.22 -0.20 -0.02 -0.10 -0.08 -0.05
# 2020Q2    nan -0.35   nan -0.56 -0.45 -0.41   nan   nan   nan -0.33
#
# country  Equal Weighted Mean
# date
# 2019Q2                  0.01
# 2019Q3                  0.01
# 2019Q4                 -0.00
# 2020Q1                 -0.10
# 2020Q2                 -0.42

# %%
random_weights = {country: np.random.uniform() for country in all_countries}
RGDPChangeMeans['Random Weighted Mean'] = sum([random_weights[country] * RGDPChangeQoQ[country] for country in countries])
RGDPChangeMeans['Random Weighted Mean'] /= sum(random_weights.values()) # Need to either do this or normalize the weights
RGDPChangeMeans.tail()
# Out:
# country   AUS   DEU   CAN   ESP   FRA   ITA   JPN   CHE   GBR   USA  \
# date
# 2019Q2   0.02 -0.02  0.03  0.02  0.01  0.00  0.02  0.01 -0.00  0.01
# 2019Q3   0.02  0.01  0.01  0.02  0.01  0.00  0.00  0.02  0.02  0.03
# 2019Q4   0.02 -0.00  0.01  0.02 -0.01 -0.01 -0.07  0.01 -0.00  0.02
# 2020Q1  -0.01 -0.08 -0.08 -0.19 -0.22 -0.20 -0.02 -0.10 -0.08 -0.05
# 2020Q2    nan -0.35   nan -0.56 -0.45 -0.41   nan   nan   nan -0.33
#
# country  Equal Weighted Mean  Random Weighted Mean
# date
# 2019Q2                  0.01                  0.00
# 2019Q3                  0.01                  0.00
# 2019Q4                 -0.00                  0.00
# 2020Q1                 -0.10                 -0.00
# 2020Q2                 -0.42                   nan

# %% [markdown]
# ## Exercises
# ### Calculate the rolling 1-year return of a world bond portfolio that is weighted by GDP of each country. Say that you instantly rebalance at the beginning of each quarter with the GDP from last quarter.

# %%
#1 Look at the bond yields across countries. Which countires have produced the highest and lowest returns?

# %%
bond_yields = LongMinusShortRates
bond_yields.plot()
plt.show()

# %%
bond_yields.tail()
bond_yields.max()
# Out:
# country
# AUS   2.64
# DEU   2.76
# CAN   2.37
# ESP   3.27
# FRA   2.56
# ITA   3.24
# JPN   2.39
# CHE   2.22
# GBR   3.04
# USA   2.83
# dtype: float64

# %%
bond_yields.min()
# Out:
# country
# AUS   -2.20
# DEU   -1.26
# CAN   -1.44
# ESP   -1.85
# FRA   -1.02
# ITA   -1.46
# JPN   -0.56
# CHE   -0.03
# GBR   -1.16
# USA   -2.04
# dtype: float64

# %% [markdown]
# Maxmimum: 3.24, ITA //
# Minimum: -2.20, AUS

# %%
annual_returns = BondReturnIndex.pct_change(365)
annual_returns.mean()
# Out:
# country
# AUS   0.14
# DEU   0.10
# CAN   0.11
# ESP   0.13
# FRA   0.11
# ITA   0.13
# JPN   0.06
# CHE   0.07
# GBR   0.14
# USA   0.11
# dtype: float64

# %% [markdown]
# Highest average: AUS //
# Lowest average: JPN

# %% [markdown]
# #2: Look at rolling 3 year returns. Pick a window when a country strongly out performs the rest of the world and case where one underperforms. What was going on in each market at these times?
#
# The returns for between 2011 and 2013 for Australia are especially high.
#
# The returns for Japan in practically all years, but especially 2018-2020, are incredibly low.

# %%
RGDPChangeRollingMean = RGDPChangeQoQ.rolling(40, min_periods=20).mean() # 
RGDPChangeRollingMean.plot()
plt.title('GDP Growth Rolling Mean (20 Year)')
plt.show()
RGDPChangeRollingStdDev = RGDPChangeQoQ.rolling(40, min_periods=20).std()
RGDPChangeRollingStdDev.plot()
plt.title('GDP Growth Rolling Std Dev (20 Year)')
plt.show()

# %%
BondReturnIndex = dl.pull('BondRetIdx/LocalFX')
BondReturnIndex.plot()
plt.xlabel('Date')
plt.ylabel('Return Index')
plt.title('Bond Return Index By Country')
plt.show()

# %%
BondReturnIndex.tail()
rBondReturn = BondReturnIndex.rolling(3).mean()
#LongRates.loc[[pd.Period('2020-03'), pd.Period('2020-04')], ['AUS', 'DEU']]
rBondReturn.tail()
LongRates.columns
[pd.Period('2020-03-01'), pd.Period('2020-04-01')]
# Out:
# [Period('2020-03-01', 'D'), Period('2020-04-01', 'D')]

# %%
rBondReturn.plot()

# %%
rbondReturn = rBondReturn.loc[pd.Period('2011-07-01'):pd.Period('2013-03-02'), :]
rbondReturn.plot()

# %%
rbondReturn = rBondReturn.loc[pd.Period('2018-07-01'):pd.Period('2020-03-02'), :]
rbondReturn.plot()

# %% [markdown]
# #3: In your data library, you have data series capturing total bond returns in local currency. You also have currency exchange rates. Let's pretend you could hedge your currency exposure perfectly and only pay 20bps to do so. How different would your hedged and unhedged returns be in each country? Why are British hedged and unhedged returns so different around the end of 1992?

# %%
#hedged: same as BondReturnIndex
#unhedged: take pct_change of FxVsUSD; Rt = (1+Rlocal)*(1+Xt)-1, where Xt = pct_change(foreign_currency)
# = convert_to_fx(return of bond)*(1+pct_change_fx)

# %%
#hedged:
hedged = (BondReturnIndex)*.98
hedged.plot()

# %%
#unhedged:

annual_returns = BondReturnIndex.pct_change(365)
annual_returns.plot()

# %%
fxVsUSD = dl.pull("fxVsUSD")
fx_change = fxVsUSD.pct_change(12)
fx_change.plot()

# %%
unhedged = annual_returns * (1-fx_change)

# %% [markdown]
# #4: How addiditve are passively holding (hedged) global bonds to a US 60/40 portfolio...

# %%
#average returns of 60/40 portfolio
bonds_annual_returns = BondReturnIndex.pct_change(365)["USA"]

equity_prices = dl.pull("EquityPrices")
equity_annual_returns = equity_prices["USA"].pct_change(365)

portfolio_returns = (equity_annual_returns*.6 + bonds_annual_returns*.4)

#HOW TO MAKE IT RISK ADJUSTED?
#risk_adjusted = portfolio_returns -  #subtract IR

# %%
portfolio_returns.plot()
plot.show()

# %%
#volatility of 60/40 portfolio
vol = portfolio_returns.rolling(365).std()*math.sqrt(365) #annualize it by multiplying by sqrt 252?
vol.plot()
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-284-14b703dc45f5> in <module>
#       1 #volatility of 60/40 portfolio
# ----> 2 vol = portfolio_returns.rolling(365).std()*math.sqrt(365) #annualize it by multiplying by sqrt 252?
#       3 vol.plot()
#       4 plot.show()
#
# NameError: name 'math' is not defined

# %%
#sharpe ratio of portfolio over time
sharpe_ratio = portfolio_returns/vol

# %%
sharpe_ratio.plot()

# %%
global_bonds_portfolio =

# %%
BondReturnIndex.plot()

# %%
#look at how monetary supply and bond_returns changed together

#USA
#prediction: as rate of monetary supply going up exceeds rate of output going up by a certain threshold, 
            #I expect interest rates to promptly rise, thus reducing bond returns. The interest will rise
            #because of the increasing rate of inflation. 
        
            #Specifics: When 3-month, 6 month rate of M1 growth rises above the 12-month, 24 months rate of growth. 
            
            #Compare how these relationships exist among M1, M2, and M3.

# %%
rbondReturn = rBondReturn.loc[pd.Period('2011-07-01'):pd.Period('2013-03-02'), :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-458863949c91> in <module>
# ----> 1 rbondReturn = rBondReturn.loc[pd.Period('2011-07-01'):pd.Period('2013-03-02'), :]
#
# NameError: name 'rBondReturn' is not defined

# %%
m2 = dl.pull("M2/inUSD").loc[[pd.Period('2020-')]]["JPN"]
m2.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-39-36f06bf6616f> in <module>
# ----> 1 m2.loc[[pd.Period('1996-01'), pd.Period('2007-01')], ['JPN']]
#       2 m2 = dl.pull("M2/inUSD").loc[[pd.Period('2020-')]]["JPN"]
#       3 m2.plot()
#       4 plt.show()
#
# ~/.local/share/virtualenvs/Intership2020-kmXmYgLs/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/.local/share/virtualenvs/Intership2020-kmXmYgLs/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     871
#     872         # no multi-index, so validate all of the indexers
# --> 873         self._has_valid_tuple(tup)
#     874
#     875         # ugly hack for GH #836
#
# ~/.local/share/virtualenvs/Intership2020-kmXmYgLs/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     219         for i, k in enumerate(key):
#     220             if i >= self.obj.ndim:
# --> 221                 raise IndexingError('Too many indexers')
#     222             try:
#     223                 self._validate_key(k, i)
#
# IndexingError: Too many indexers

# %%
m2.loc[[pd.Period('2020-03'), pd.Period('2020-04')]]
# Out:
# date
# 2020-03   9,776.08
# 2020-04   9,882.30
# Freq: M, Name: JPN, dtype: float64

# %%
BondReturnIndex["JPN"].plot()
plt.show()
