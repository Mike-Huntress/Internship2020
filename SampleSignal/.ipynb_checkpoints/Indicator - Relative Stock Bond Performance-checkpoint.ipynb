# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import matplotlib.pyplot as plt
from BasicSetupUtilities.MetaDataBuilder import CountryMetaDataFile
from DataIOUtilities.DataLib import DataLib, DatastreamPulls
import pandas as pd
import numpy as np
import sklearn.preprocessing

# %%
WEEKDAYS_IN_YEAR = 261
DAYS_IN_MONTH = 20

dl = DataLib("SignalData")
BondReturnIdx = dl.pull("BondRetIdx/LocalFX")
fxvsusd = dl.pull("fxVsUSD")
equities = dl.pull("EquityPrices")
m1 = dl.pull("M1/inUSD")
m2 = dl.pull("M2/inUSD")
m3 = dl.pull("M3/inUSD")
curr_acct_nom = dl.pull("CurrAcctNom/inUSD")
curr_acct_gdp = dl.pull("CurrAcctPctGDP")
LongRates = dl.pull("LongRates")
ShortRates = dl.pull("ShortRates")
fxNominal = dl.pull("fxTrdWts/Nominal")
fxReal = dl.pull("fxTrdWts/Real")
core_cpi = dl.pull("CoreCPI/SA")
gdp_real = dl.pull("GDP/Real")

# %%
equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
equity_risk_adjusted = equity_ret / equity_ret.std()
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
bond_risk_adjusted = bond_ret / bond_ret.std()

country = "CAN"
start_date = '1990-01-01'
end_date = '2000-01-01'
equity_risk_adjusted[country].loc[start_date:end_date].plot(label = "equities")
bond_risk_adjusted[country].loc[start_date:end_date].plot(label = "bonds")
plt.legend()
plt.title("Equities vs. Bond Returns - Risk Adjusted " + country)
plt.show()

equity_risk_adjusted_outperformance = (equity_risk_adjusted - bond_risk_adjusted)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1_label = 'Equity Outperformance'
ax1.plot(equity_risk_adjusted_outperformance[country].loc[start_date:end_date].to_timestamp(), label = ax1_label)
ax1.set_ylabel(ax1_label)
ax1.legend()
ax2_label = '10 Year Bond Yields'
ax2.plot(LongRates[country].loc[start_date:end_date].to_timestamp(), color = 'tab:red', label = ax2_label)
ax2.set_ylabel(ax2_label)
ax2.legend(loc = "lower left")
plt.title(country + " - Equity Outperformance (Risk-Adjusted) vs. Bond Yields")
plt.show()

# %%
def calc_corr(m_period_data, b_period_data):
    interpolated_data = m_period_data.resample('B').interpolate(method='linear')
    return interpolated_data.corr(d_period_data)

# %%
start_date = "2017-06-01"
end_date = "2018-12-01"
training_eq = equity_ret.loc[start_date:end_date]
training_bond = bond_ret.loc[start_date:end_date]
equities_risk_adj = training_eq/training_eq.std()
bond_risk_adj = training_bond/training_bond.std()
outperformance = equities_risk_adj - bond_risk_adj
outperformance = outperformance.rolling(20).mean()


one_day_returns = BondReturnIdx.pct_change(1)
for country in equities.columns:
    fig, ax1 = plt.subplots()
    ax2 = ax1.twinx()
    ax1_label = 'Equity Outperformance'
    ax1.plot(outperformance[country].loc[start_date:end_date].to_timestamp(), label = ax1_label)
    ax1.set_ylabel(ax1_label)
    ax1.legend()
    ax2_label = '10 Year Bond Yields'
    ax2.plot(LongRates[country].loc[start_date:end_date].to_timestamp(), color = 'tab:red', label = ax2_label)
    ax2.set_ylabel(ax2_label)
    ax2.legend(loc = "lower left")
    plt.title(country + " - Equity Outperformance (Risk-Adjusted) vs. Bond Yields")
    plt.show()
#     print("Corr between Equity Outperformance and Bond Yields " + country)
#     print(calc_corr(LongRates[country].loc[start_date:end_date],outperformance[country].loc[start_date:end_date]))
    
#     fig, ax1 = plt.subplots()
#     ax2 = ax1.twinx()
#     ax1_label = 'Equity Outperformance'
#     ax1.plot(outperformance[country].loc[start_date:end_date].to_timestamp(), label = ax1_label)
#     ax1.set_ylabel(ax1_label)
#     ax1.legend()
#     ax2_label = 'Bond Returns'
#     ax2.plot(one_day_returns[country].loc[start_date:end_date].to_timestamp(), color = 'tab:red', label = ax2_label)
#     ax2.set_ylabel(ax2_label)
#     ax2.legend(loc = "lower left")
#     plt.title(country + " - Equity Outperformance (Risk-Adjusted) vs. Bond Returns")
#     plt.show()

# %% [markdown]
# **Takeaways**:
# - When country-specific equity out-performance exceeds that of global equity outperformance, the country is far more likely to experience bond yields rise. Weighting across countries will be standardized around global avg.
# - Percentage change in Equity Outperformance

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
#     global_mean = outperformance.mean()
#     global_std = outperformance.std()
#     positions = (outperformance - global_mean)/global_std
    

    movt_outperformance = outperformance.diff()
    global_mean = movt_outperformance.mean(axis = 1).loc[end_date]
    global_std = movt_outperformance.std(axis = 1).loc[end_date]
    curr_outperformance = movt_outperformance.loc[end_date]
    
    # if diff is positive, then short bonds
    short_pos = curr_outperformance.multiply(curr_outperformance.gt(0))
    short_pos = short_pos * -1

    # if diff is negative, then long bonds 
    long_pos = curr_outperformance.multiply(curr_outperformance.lt(0))
    positions = short_pos + long_pos 
    positions = (positions - global_mean)/global_std
#    positions_track.loc[date] = positions
    
    #daily_pl.loc[date] = positions.dot(one_day_returns.loc[date])
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
    if daily_ret.loc[date].values < -.0075:
        print(positions)
        print(curr_outperformance)
    
    end_date = date
daily_ret.plot()
plt.show()
# Out:
# country
# AUS   -1.310493
# CAN   -0.750831
# CHE   -1.145452
# DEU   -2.279655
# ESP   -2.265336
# FRA   -3.163052
# GBR   -0.776963
# ITA   -1.773568
# JPN   -0.981439
# USA   -1.065584
# Name: 2015-06-10, dtype: float64
# country
# AUS   -0.007364
# CAN    0.000933
# CHE    0.005468
# DEU    0.018501
# ESP    0.018336
# FRA    0.028652
# GBR   -0.001234
# ITA    0.012685
# JPN   -0.003583
# USA    0.004550
# Name: 2015-06-10, dtype: float64

# %%
daily_ret.cumsum().plot()
plt.show()

daily_ret.std()
# Out:
# Returns    0.002177
# dtype: float64

# %%
#daily_pl.sum()
daily_ret.cumsum().plot()
plt.show()

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
    global_mean = outperformance.loc[end_date].mean()
    global_std = outperformance.loc[end_date].std()
    positions = (outperformance.loc[end_date] - global_mean)/global_std

    diffs = outperformance.diff().loc[end_date]
    pos_diffs = diffs.multiply(diffs.gt(0))
    if pos_diffs.sum() != 0:
        scaled_pos_diffs = pos_diffs / pos_diffs.sum()
    neg_diffs = diffs.multiply(diffs.lt(0))
    if neg_diffs.sum() != 0:
        scaled_neg_diffs = neg_diffs / neg_diffs.sum()
    weights = scaled_pos_diffs + scaled_neg_diffs
    positions = positions.multiply(weights)
#     print(weights)
    
#     diffs = outperformance.diff().abs().loc[end_date]
#     weights = diffs/diffs.sum()
#     positions = positions.multiply(weights)
#     print(weights)
    
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
#     if daily_ret.loc[date].values < -.004:
#         print(positions)
#         print(outperformance.loc[end_date])
    
    end_date = date
daily_ret.plot()
plt.show()

# %%
daily_ret.cumsum().plot()
plt.show()

daily_ret.std()
# Out:
# Returns    0.00164
# dtype: float64

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
    global_mean = outperformance.loc[end_date].mean()
    global_std = outperformance.loc[end_date].std()
    positions = (outperformance.loc[end_date] - global_mean)/global_std
    
    diffs = outperformance.diff().abs().loc[end_date]
    weights = diffs/diffs.sum()
    positions = positions.multiply(weights)
    print(positions)
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
#     if daily_ret.loc[date].values < -.004:
#         print(positions)
#         print(outperformance.loc[end_date])
    
    end_date = date
daily_ret.plot()
plt.show()
# Out:
# country
# AUS   -0.006179
# CAN    0.037414
# CHE    0.054132
# DEU   -0.136288
# ESP   -0.069094
# FRA   -0.180283
# GBR   -0.070985
# ITA   -0.033463
# JPN    0.209407
# USA    0.133433
# Name: 2015-01-01, dtype: float64
# country
# AUS   -0.004111
# CAN    0.037139
# CHE    0.058545
# DEU   -0.147486
# ESP   -0.052488
# FRA   -0.186092
# GBR   -0.079307
# ITA   -0.034221
# JPN    0.205910
# USA    0.136779
# Name: 2015-01-02, dtype: float64
# country
# AUS   -0.005586
# CAN    0.030981
# CHE    0.071721
# DEU   -0.132724
# ESP   -0.053413
# FRA   -0.168593
# GBR   -0.081435
# ITA   -0.043643
# JPN    0.188442
# USA    0.130517
# Name: 2015-01-05, dtype: float64
# country
# AUS   -0.006843
# CAN    0.039529
# CHE    0.063025
# DEU   -0.122988
# ESP   -0.047189
# FRA   -0.163691
# GBR   -0.068509
# ITA   -0.041008
# JPN    0.198847
# USA    0.155466
# Name: 2015-01-06, dtype: float64
# country
# AUS   -0.004978
# CAN    0.030219
# CHE    0.081699
# DEU   -0.137408
# ESP   -0.057395
# FRA   -0.168653
# GBR   -0.078939
# ITA   -0.042827
# JPN    0.158484
# USA    0.135060
# Name: 2015-01-07, dtype: float64
# country
# AUS   -0.003374
# CAN    0.029860
# CHE    0.080248
# DEU   -0.131309
# ESP   -0.073378
# FRA   -0.137208
# GBR   -0.066633
# ITA   -0.052983
# JPN    0.196879
# USA    0.138864
# Name: 2015-01-08, dtype: float64
# country
# AUS   -0.002846
# CAN    0.017011
# CHE    0.085450
# DEU   -0.130266
# ESP   -0.084856
# FRA   -0.134597
# GBR   -0.052403
# ITA   -0.059923
# JPN    0.233031
# USA    0.131884
# Name: 2015-01-09, dtype: float64
# country
# AUS   -0.004551
# CAN    0.025976
# CHE    0.089673
# DEU   -0.089358
# ESP   -0.087241
# FRA   -0.118658
# GBR   -0.045119
# ITA   -0.059050
# JPN    0.216544
# USA    0.151031
# Name: 2015-01-12, dtype: float64
# country
# AUS   -0.008629
# CAN    0.022115
# CHE    0.088498
# DEU   -0.061145
# ESP   -0.118007
# FRA   -0.089648
# GBR   -0.035120
# ITA   -0.079684
# JPN    0.250588
# USA    0.054607
# Name: 2015-01-13, dtype: float64
# country
# AUS   -0.002590
# CAN    0.071143
# CHE    0.078436
# DEU   -0.070936
# ESP   -0.083833
# FRA   -0.136648
# GBR   -0.059285
# ITA   -0.062134
# JPN    0.106449
# USA    0.181242
# Name: 2015-01-14, dtype: float64
# country
# AUS   -0.000886
# CAN    0.069300
# CHE    0.152281
# DEU   -0.073265
# ESP   -0.054714
# FRA   -0.117109
# GBR   -0.061599
# ITA   -0.045132
# JPN    0.093686
# USA    0.197977
# Name: 2015-01-15, dtype: float64
# country
# AUS   -0.003129
# CAN    0.047305
# CHE    0.206807
# DEU   -0.028136
# ESP   -0.045712
# FRA   -0.088279
# GBR   -0.048785
# ITA   -0.035156
# JPN    0.156019
# USA    0.160225
# Name: 2015-01-16, dtype: float64
# country
# AUS   -0.001743
# CAN    0.058120
# CHE    0.222810
# DEU   -0.032764
# ESP   -0.029471
# FRA   -0.076433
# GBR   -0.054076
# ITA   -0.023923
# JPN    0.177121
# USA    0.167036
# Name: 2015-01-19, dtype: float64
# country
# AUS   -0.000299
# CAN    0.101225
# CHE    0.229460
# DEU   -0.008284
# ESP   -0.007322
# FRA   -0.050338
# GBR   -0.051695
# ITA   -0.015680
# JPN    0.145320
# USA    0.220669
# Name: 2015-01-20, dtype: float64
# country
# AUS    0.000015
# CAN    0.088331
# CHE    0.248182
# DEU   -0.022718
# ESP   -0.005050
# FRA   -0.016146
# GBR   -0.048741
# ITA   -0.008031
# JPN    0.182094
# USA    0.153359
# Name: 2015-01-21, dtype: float64
# country
# AUS    0.000558
# CAN    0.084389
# CHE    0.239896
# DEU   -0.009222
# ESP   -0.011778
# FRA   -0.051404
# GBR   -0.047328
# ITA   -0.013398
# JPN    0.108492
# USA    0.161359
# Name: 2015-01-22, dtype: float64
# country
# AUS    0.000011
# CAN    0.088577
# CHE    0.221210
# DEU   -0.033050
# ESP   -0.015567
# FRA   -0.031199
# GBR   -0.027509
# ITA   -0.022565
# JPN    0.093449
# USA    0.158822
# Name: 2015-01-23, dtype: float64
# country
# AUS    0.000581
# CAN    0.021742
# CHE    0.135063
# DEU   -0.209833
# ESP   -0.045121
# FRA   -0.209029
# GBR   -0.060287
# ITA   -0.004583
# JPN    0.009808
# USA    0.024954
# Name: 2015-01-26, dtype: float64
# country
# AUS    0.002216
# CAN    0.031984
# CHE    0.059585
# DEU   -0.151899
# ESP   -0.056773
# FRA   -0.193763
# GBR   -0.062099
# ITA   -0.011029
# JPN    0.235945
# USA    0.049055
# Name: 2015-01-27, dtype: float64
# country
# AUS    0.006507
# CAN    0.037490
# CHE    0.045680
# DEU   -0.118550
# ESP   -0.051112
# FRA   -0.146175
# GBR   -0.054343
# ITA   -0.017438
# JPN    0.250920
# USA    0.070580
# Name: 2015-01-28, dtype: float64
# country
# AUS    0.004083
# CAN    0.022906
# CHE    0.036384
# DEU   -0.165764
# ESP   -0.060285
# FRA   -0.210278
# GBR   -0.061832
# ITA   -0.026291
# JPN    0.184367
# USA    0.012709
# Name: 2015-01-29, dtype: float64
# country
# AUS    0.004681
# CAN    0.051635
# CHE    0.025416
# DEU   -0.137875
# ESP   -0.016395
# FRA   -0.179526
# GBR   -0.043536
# ITA   -0.022138
# JPN    0.248398
# USA    0.098901
# Name: 2015-01-30, dtype: float64
# country
# AUS    0.008417
# CAN    0.002127
# CHE    0.009173
# DEU   -0.161799
# ESP   -0.028079
# FRA   -0.226103
# GBR   -0.078012
# ITA   -0.042980
# JPN    0.223172
# USA    0.034912
# Name: 2015-02-02, dtype: float64
# country
# AUS    0.007560
# CAN    0.021022
# CHE    0.000453
# DEU   -0.120537
# ESP   -0.043365
# FRA   -0.182070
# GBR   -0.068070
# ITA   -0.044039
# JPN    0.234478
# USA    0.130277
# Name: 2015-02-03, dtype: float64
# country
# AUS    0.016011
# CAN    0.010606
# CHE   -0.001820
# DEU   -0.124015
# ESP   -0.027252
# FRA   -0.178614
# GBR   -0.069895
# ITA   -0.030667
# JPN    0.349085
# USA    0.084457
# Name: 2015-02-04, dtype: float64
# country
# AUS    0.023413
# CAN    0.010529
# CHE   -0.007207
# DEU   -0.109323
# ESP   -0.030543
# FRA   -0.157935
# GBR   -0.059209
# ITA   -0.027387
# JPN    0.342979
# USA    0.093153
# Name: 2015-02-05, dtype: float64
# country
# AUS    0.019426
# CAN    0.011914
# CHE   -0.014329
# DEU   -0.093139
# ESP   -0.046383
# FRA   -0.151411
# GBR   -0.057263
# ITA   -0.029598
# JPN    0.324267
# USA    0.120059
# Name: 2015-02-06, dtype: float64
# country
# AUS    0.022685
# CAN    0.010436
# CHE   -0.022152
# DEU   -0.072966
# ESP   -0.066473
# FRA   -0.133391
# GBR   -0.050935
# ITA   -0.043300
# JPN    0.312803
# USA    0.111679
# Name: 2015-02-09, dtype: float64
# country
# AUS    0.026241
# CAN    0.009232
# CHE   -0.026436
# DEU   -0.064077
# ESP   -0.078923
# FRA   -0.127813
# GBR   -0.043584
# ITA   -0.046077
# JPN    0.336466
# USA    0.105814
# Name: 2015-02-10, dtype: float64
# country
# AUS    0.019750
# CAN    0.011801
# CHE   -0.023238
# DEU   -0.063855
# ESP   -0.075258
# FRA   -0.138838
# GBR   -0.049412
# ITA   -0.047523
# JPN    0.299168
# USA    0.131673
# Name: 2015-02-11, dtype: float64
# country
# AUS    0.009864
# CAN    0.014992
# CHE   -0.020289
# DEU   -0.062493
# ESP   -0.076986
# FRA   -0.119479
# GBR   -0.042125
# ITA   -0.045571
# JPN    0.337443
# USA    0.193906
# Name: 2015-02-12, dtype: float64
# country
# AUS    0.021684
# CAN    0.005398
# CHE   -0.045489
# DEU   -0.054416
# ESP   -0.071088
# FRA   -0.105617
# GBR   -0.035230
# ITA   -0.038291
# JPN    0.378329
# USA    0.146128
# Name: 2015-02-13, dtype: float64
# country
# AUS    0.018866
# CAN    0.004339
# CHE   -0.050344
# DEU   -0.046756
# ESP   -0.065810
# FRA   -0.092243
# GBR   -0.036827
# ITA   -0.033780
# JPN    0.470374
# USA    0.132446
# Name: 2015-02-16, dtype: float64
# country
# AUS    0.014305
# CAN    0.008293
# CHE   -0.052248
# DEU   -0.044467
# ESP   -0.064182
# FRA   -0.083624
# GBR   -0.036584
# ITA   -0.037414
# JPN    0.369693
# USA    0.168433
# Name: 2015-02-17, dtype: float64
# country
# AUS    0.014785
# CAN    0.004832
# CHE   -0.061392
# DEU   -0.039118
# ESP   -0.068216
# FRA   -0.084164
# GBR   -0.036995
# ITA   -0.042962
# JPN    0.351561
# USA    0.129642
# Name: 2015-02-18, dtype: float64
# country
# AUS    0.008968
# CAN    0.001643
# CHE   -0.057758
# DEU   -0.050439
# ESP   -0.068977
# FRA   -0.107128
# GBR   -0.034416
# ITA   -0.045644
# JPN    0.333252
# USA    0.139385
# Name: 2015-02-19, dtype: float64
# country
# AUS    0.006880
# CAN    0.000264
# CHE   -0.053077
# DEU   -0.047217
# ESP   -0.067342
# FRA   -0.088715
# GBR   -0.026190
# ITA   -0.047821
# JPN    0.456638
# USA    0.148255
# Name: 2015-02-20, dtype: float64
# country
# AUS    0.007642
# CAN    0.000459
# CHE   -0.051812
# DEU   -0.022928
# ESP   -0.069257
# FRA   -0.048163
# GBR   -0.022068
# ITA   -0.056925
# JPN    0.524897
# USA    0.116438
# Name: 2015-02-23, dtype: float64
# country
# AUS    0.004931
# CAN   -0.001707
# CHE   -0.033814
# DEU   -0.054191
# ESP   -0.062289
# FRA   -0.052423
# GBR   -0.023775
# ITA   -0.062692
# JPN    0.484857
# USA    0.126628
# Name: 2015-02-24, dtype: float64
# country
# AUS    0.002092
# CAN   -0.001042
# CHE   -0.031273
# DEU   -0.064493
# ESP   -0.055070
# FRA   -0.066067
# GBR   -0.025456
# ITA   -0.047787
# JPN    0.336850
# USA    0.287307
# Name: 2015-02-25, dtype: float64
# country
# AUS    0.000450
# CAN   -0.001247
# CHE   -0.023692
# DEU   -0.054997
# ESP   -0.047085
# FRA   -0.057631
# GBR   -0.039582
# ITA   -0.039345
# JPN    0.599787
# USA    0.211739
# Name: 2015-02-26, dtype: float64
# country
# AUS    0.001650
# CAN   -0.003113
# CHE   -0.020748
# DEU   -0.074942
# ESP   -0.048925
# FRA   -0.086421
# GBR   -0.038935
# ITA   -0.041311
# JPN    0.331180
# USA    0.225254
# Name: 2015-02-27, dtype: float64
# country
# AUS    0.002118
# CAN   -0.004406
# CHE   -0.020201
# DEU   -0.041262
# ESP   -0.056057
# FRA   -0.040724
# GBR   -0.032935
# ITA   -0.039556
# JPN    0.450768
# USA    0.253517
# Name: 2015-03-02, dtype: float64
# country
# AUS    0.004630
# CAN   -0.001473
# CHE   -0.031838
# DEU   -0.066307
# ESP   -0.036938
# FRA   -0.055798
# GBR   -0.034758
# ITA   -0.032399
# JPN    0.495924
# USA    0.122319
# Name: 2015-03-03, dtype: float64
# country
# AUS    0.001306
# CAN   -0.002314
# CHE   -0.025089
# DEU   -0.047150
# ESP   -0.120547
# FRA   -0.019948
# GBR   -0.030625
# ITA   -0.083675
# JPN    0.223107
# USA    0.211894
# Name: 2015-03-04, dtype: float64
# country
# AUS    0.001787
# CAN   -0.000554
# CHE   -0.023541
# DEU   -0.042281
# ESP   -0.087289
# FRA   -0.032930
# GBR   -0.030324
# ITA   -0.061904
# JPN    0.405638
# USA    0.088982
# Name: 2015-03-05, dtype: float64
# country
# AUS   -0.001221
# CAN   -0.001610
# CHE   -0.006413
# DEU   -0.133804
# ESP   -0.022765
# FRA   -0.101933
# GBR   -0.040052
# ITA   -0.044695
# JPN    0.358212
# USA    0.075561
# Name: 2015-03-06, dtype: float64
# country
# AUS   -0.003966
# CAN   -0.005876
# CHE   -0.014505
# DEU   -0.112388
# ESP   -0.042264
# FRA   -0.074159
# GBR   -0.036847
# ITA   -0.057921
# JPN    0.370242
# USA    0.009929
# Name: 2015-03-09, dtype: float64
# country
# AUS   -0.003702
# CAN   -0.014543
# CHE   -0.011331
# DEU   -0.078514
# ESP   -0.033354
# FRA   -0.081240
# GBR   -0.010906
# ITA   -0.024011
# JPN    0.480412
# USA    0.192121
# Name: 2015-03-10, dtype: float64
# country
# AUS   -0.008296
# CAN   -0.011704
# CHE   -0.019192
# DEU   -0.153637
# ESP   -0.018409
# FRA   -0.005065
# GBR   -0.008862
# ITA   -0.019639
# JPN    0.382978
# USA    0.118855
# Name: 2015-03-11, dtype: float64
# country
# AUS   -0.001337
# CAN   -0.001653
# CHE   -0.024701
# DEU   -0.177251
# ESP   -0.024219
# FRA   -0.118090
# GBR   -0.026442
# ITA   -0.013338
# JPN    0.413796
# USA    0.016660
# Name: 2015-03-12, dtype: float64
# country
# AUS   -0.006273
# CAN   -0.003730
# CHE   -0.028234
# DEU   -0.163448
# ESP   -0.010842
# FRA   -0.147474
# GBR   -0.018328
# ITA   -0.000933
# JPN    0.299772
# USA    0.012626
# Name: 2015-03-13, dtype: float64
# country
# AUS   -0.005427
# CAN   -0.005585
# CHE   -0.018857
# DEU   -0.140636
# ESP   -0.008751
# FRA   -0.168406
# GBR   -0.022462
# ITA   -0.022034
# JPN    0.266761
# USA    0.046804
# Name: 2015-03-16, dtype: float64
# country
# AUS   -0.001030
# CAN   -0.009771
# CHE   -0.013167
# DEU   -0.117536
# ESP   -0.009338
# FRA   -0.139995
# GBR   -0.018558
# ITA   -0.000964
# JPN    0.535049
# USA    0.085718
# Name: 2015-03-17, dtype: float64
# country
# AUS   -0.002676
# CAN   -0.018764
# CHE   -0.009897
# DEU   -0.086079
# ESP   -0.013634
# FRA   -0.078194
# GBR   -0.008422
# ITA   -0.020912
# JPN    0.627906
# USA    0.151819
# Name: 2015-03-18, dtype: float64
# country
# AUS   -0.002450
# CAN   -0.032200
# CHE   -0.010633
# DEU   -0.063296
# ESP   -0.032373
# FRA   -0.030680
# GBR   -0.005153
# ITA   -0.032849
# JPN    0.527136
# USA    0.202359
# Name: 2015-03-19, dtype: float64
# country
# AUS   -0.007360
# CAN   -0.029041
# CHE   -0.010269
# DEU   -0.054079
# ESP   -0.014161
# FRA   -0.057196
# GBR   -0.015879
# ITA   -0.022856
# JPN    0.480336
# USA    0.184007
# Name: 2015-03-20, dtype: float64
# country
# AUS   -0.000540
# CAN   -0.019755
# CHE   -0.001936
# DEU   -0.044419
# ESP   -0.056984
# FRA   -0.094185
# GBR   -0.018350
# ITA   -0.023203
# JPN    0.687625
# USA    0.161065
# Name: 2015-03-23, dtype: float64
# country
# AUS   -0.002980
# CAN   -0.003557
# CHE   -0.005972
# DEU   -0.053924
# ESP   -0.091262
# FRA   -0.148933
# GBR   -0.022249
# ITA   -0.063107
# JPN    0.391403
# USA    0.071628
# Name: 2015-03-24, dtype: float64
# country
# AUS   -0.000549
# CAN   -0.013056
# CHE   -0.009451
# DEU   -0.040727
# ESP   -0.086175
# FRA   -0.108033
# GBR   -0.009583
# ITA   -0.052995
# JPN    0.566729
# USA    0.114289
# Name: 2015-03-25, dtype: float64
# country
# AUS   -0.000167
# CAN   -0.003282
# CHE   -0.005429
# DEU   -0.038901
# ESP   -0.137566
# FRA   -0.098062
# GBR   -0.002348
# ITA   -0.065378
# JPN    0.511410
# USA    0.136117
# Name: 2015-03-26, dtype: float64
# country
# AUS   -0.002677
# CAN   -0.013824
# CHE   -0.009756
# DEU   -0.022266
# ESP   -0.144017
# FRA   -0.078808
# GBR   -0.017340
# ITA   -0.048440
# JPN    0.492847
# USA    0.102079
# Name: 2015-03-27, dtype: float64
# country
# AUS   -0.023382
# CAN   -0.029525
# CHE   -0.015496
# DEU   -0.023914
# ESP   -0.077425
# FRA   -0.083312
# GBR   -0.012907
# ITA   -0.024751
# JPN    0.260784
# USA    0.124239
# Name: 2015-03-30, dtype: float64
# country
# AUS   -0.029455
# CAN   -0.041619
# CHE   -0.002991
# DEU   -0.010172
# ESP   -0.027483
# FRA   -0.043703
# GBR   -0.051345
# ITA   -0.061785
# JPN    0.036435
# USA    0.211907
# Name: 2015-03-31, dtype: float64
# country
# AUS   -0.041554
# CAN   -0.061873
# CHE   -0.000868
# DEU   -0.004908
# ESP   -0.018611
# FRA   -0.041344
# GBR   -0.049973
# ITA   -0.039030
# JPN    0.019080
# USA    0.211279
# Name: 2015-04-01, dtype: float64
# country
# AUS   -0.047461
# CAN   -0.075483
# CHE   -0.000993
# DEU   -0.011374
# ESP   -0.029098
# FRA   -0.052302
# GBR   -0.045356
# ITA   -0.010676
# JPN    0.005888
# USA    0.174316
# Name: 2015-04-02, dtype: float64
# country
# AUS   -0.038674
# CAN   -0.071573
# CHE   -0.006122
# DEU   -0.009789
# ESP   -0.043390
# FRA   -0.019243
# GBR   -0.039068
# ITA   -0.018092
# JPN    0.039934
# USA    0.178450
# Name: 2015-04-03, dtype: float64
# country
# AUS   -0.049082
# CAN   -0.052650
# CHE   -0.008142
# DEU   -0.004511
# ESP   -0.048227
# FRA   -0.041097
# GBR   -0.058458
# ITA   -0.010476
# JPN    0.037073
# USA    0.104310
# Name: 2015-04-06, dtype: float64
# country
# AUS   -0.016608
# CAN   -0.000371
# CHE   -0.007912
# DEU   -0.020456
# ESP   -0.056766
# FRA   -0.167116
# GBR   -0.038255
# ITA   -0.058137
# JPN    0.223972
# USA    0.011552
# Name: 2015-04-07, dtype: float64
# country
# AUS   -0.007655
# CAN   -0.008123
# CHE   -0.004550
# DEU   -0.009961
# ESP   -0.074544
# FRA   -0.125570
# GBR   -0.024898
# ITA   -0.087209
# JPN    0.571289
# USA    0.014457
# Name: 2015-04-08, dtype: float64
# country
# AUS   -0.015623
# CAN   -0.002602
# CHE   -0.002599
# DEU   -0.012641
# ESP   -0.080533
# FRA   -0.078900
# GBR   -0.023339
# ITA   -0.117068
# JPN    0.604708
# USA    0.021994
# Name: 2015-04-09, dtype: float64
# country
# AUS   -0.003356
# CAN   -0.004516
# CHE   -0.001507
# DEU   -0.018967
# ESP   -0.099711
# FRA   -0.069702
# GBR   -0.042236
# ITA   -0.132472
# JPN    0.480997
# USA    0.009831
# Name: 2015-04-10, dtype: float64
# country
# AUS   -0.007711
# CAN   -0.020169
# CHE   -0.001984
# DEU   -0.031395
# ESP   -0.106718
# FRA   -0.046446
# GBR   -0.038377
# ITA   -0.127720
# JPN    0.267510
# USA    0.003689
# Name: 2015-04-13, dtype: float64
# country
# AUS   -0.009908
# CAN   -0.025161
# CHE   -0.002822
# DEU   -0.023929
# ESP   -0.121711
# FRA   -0.055253
# GBR   -0.014024
# ITA   -0.141307
# JPN    0.115642
# USA    0.029210
# Name: 2015-04-14, dtype: float64
# country
# AUS   -0.012335
# CAN   -0.050677
# CHE   -0.002509
# DEU   -0.023485
# ESP   -0.063594
# FRA   -0.095337
# GBR   -0.033430
# ITA   -0.104229
# JPN    0.132702
# USA    0.047727
# Name: 2015-04-15, dtype: float64
# country
# AUS   -0.005021
# CAN   -0.078704
# CHE   -0.001555
# DEU   -0.006335
# ESP   -0.086456
# FRA   -0.089674
# GBR   -0.037027
# ITA   -0.112004
# JPN    0.093965
# USA    0.044775
# Name: 2015-04-16, dtype: float64
# country
# AUS   -0.050033
# CAN   -0.076253
# CHE   -0.000757
# DEU   -0.022989
# ESP   -0.073519
# FRA   -0.060414
# GBR   -0.013701
# ITA   -0.115333
# JPN    0.158350
# USA    0.015050
# Name: 2015-04-17, dtype: float64
# country
# AUS   -0.042973
# CAN   -0.089624
# CHE   -0.000802
# DEU   -0.012884
# ESP   -0.063724
# FRA   -0.042621
# GBR   -0.020244
# ITA   -0.116272
# JPN    0.276151
# USA    0.008049
# Name: 2015-04-20, dtype: float64
# country
# AUS   -0.049128
# CAN   -0.093316
# CHE   -0.000514
# DEU   -0.063780
# ESP   -0.050152
# FRA   -0.053109
# GBR   -0.002281
# ITA   -0.072487
# JPN    0.085078
# USA    0.036737
# Name: 2015-04-21, dtype: float64
# country
# AUS   -0.031529
# CAN   -0.094329
# CHE   -0.000671
# DEU   -0.040768
# ESP   -0.027516
# FRA   -0.025959
# GBR   -0.044395
# ITA   -0.044897
# JPN    0.138746
# USA    0.094207
# Name: 2015-04-22, dtype: float64
# country
# AUS   -0.025275
# CAN   -0.048464
# CHE   -0.006309
# DEU   -0.020087
# ESP   -0.031171
# FRA   -0.061334
# GBR   -0.051543
# ITA   -0.069911
# JPN    0.329584
# USA    0.031850
# Name: 2015-04-23, dtype: float64
# country
# AUS   -0.025406
# CAN   -0.067430
# CHE   -0.004812
# DEU   -0.041436
# ESP   -0.029395
# FRA   -0.012489
# GBR   -0.046619
# ITA   -0.074795
# JPN    0.381389
# USA    0.001161
# Name: 2015-04-24, dtype: float64
# country
# AUS   -0.048235
# CAN   -0.041063
# CHE   -0.004030
# DEU   -0.020375
# ESP   -0.035506
# FRA   -0.077595
# GBR   -0.049230
# ITA   -0.078026
# JPN    0.240650
# USA    0.027324
# Name: 2015-04-27, dtype: float64
# country
# AUS   -0.041247
# CAN   -0.046155
# CHE   -0.005548
# DEU   -0.010703
# ESP   -0.031521
# FRA   -0.040847
# GBR   -0.037549
# ITA   -0.060677
# JPN    0.370088
# USA    0.076278
# Name: 2015-04-28, dtype: float64
# country
# AUS   -0.035869
# CAN   -0.054489
# CHE   -0.004560
# DEU   -0.010601
# ESP   -0.031054
# FRA   -0.062793
# GBR   -0.032626
# ITA   -0.042057
# JPN    0.347899
# USA    0.102052
# Name: 2015-04-29, dtype: float64
# country
# AUS   -0.042469
# CAN   -0.044808
# CHE   -0.005838
# DEU   -0.035255
# ESP   -0.030777
# FRA   -0.098630
# GBR   -0.027500
# ITA   -0.045651
# JPN    0.233914
# USA    0.074226
# Name: 2015-04-30, dtype: float64
# country
# AUS   -0.049269
# CAN   -0.047201
# CHE   -0.005598
# DEU   -0.030193
# ESP   -0.029902
# FRA   -0.083280
# GBR   -0.024990
# ITA   -0.042746
# JPN    0.177177
# USA    0.110418
# Name: 2015-05-01, dtype: float64
# country
# AUS   -0.046543
# CAN   -0.038619
# CHE   -0.007279
# DEU   -0.047645
# ESP   -0.030240
# FRA   -0.107488
# GBR   -0.021898
# ITA   -0.043745
# JPN    0.197547
# USA    0.079243
# Name: 2015-05-04, dtype: float64
# country
# AUS   -0.053607
# CAN   -0.033576
# CHE   -0.005695
# DEU   -0.038250
# ESP   -0.050438
# FRA   -0.110041
# GBR   -0.018063
# ITA   -0.077422
# JPN    0.085959
# USA    0.069419
# Name: 2015-05-05, dtype: float64
# country
# AUS   -0.043204
# CAN   -0.032666
# CHE   -0.006315
# DEU   -0.048637
# ESP   -0.050199
# FRA   -0.130502
# GBR   -0.019139
# ITA   -0.079254
# JPN    0.002001
# USA    0.071583
# Name: 2015-05-06, dtype: float64
# country
# AUS   -0.065886
# CAN   -0.028729
# CHE   -0.007230
# DEU   -0.054075
# ESP   -0.041590
# FRA   -0.134691
# GBR   -0.013273
# ITA   -0.068368
# JPN    0.047126
# USA    0.062871
# Name: 2015-05-07, dtype: float64
# country
# AUS   -0.036095
# CAN   -0.030748
# CHE   -0.008464
# DEU   -0.053726
# ESP   -0.048882
# FRA   -0.153405
# GBR   -0.009829
# ITA   -0.080920
# JPN    0.079632
# USA    0.052112
# Name: 2015-05-08, dtype: float64
# country
# AUS   -0.038564
# CAN   -0.037415
# CHE   -0.006066
# DEU   -0.049157
# ESP   -0.045199
# FRA   -0.143741
# GBR   -0.005920
# ITA   -0.090548
# JPN    0.014332
# USA    0.072278
# Name: 2015-05-11, dtype: float64
# country
# AUS   -0.062879
# CAN   -0.026902
# CHE   -0.007539
# DEU   -0.051730
# ESP   -0.035122
# FRA   -0.144586
# GBR   -0.009609
# ITA   -0.083977
# JPN    0.100709
# USA    0.049288
# Name: 2015-05-12, dtype: float64
# country
# AUS   -0.062805
# CAN   -0.026940
# CHE   -0.009415
# DEU   -0.047799
# ESP   -0.034615
# FRA   -0.143650
# GBR   -0.002279
# ITA   -0.081285
# JPN    0.045869
# USA    0.081417
# Name: 2015-05-13, dtype: float64
# country
# AUS   -0.043027
# CAN   -0.025290
# CHE   -0.012471
# DEU   -0.060004
# ESP   -0.029676
# FRA   -0.144351
# GBR   -0.012531
# ITA   -0.072763
# JPN    0.054982
# USA    0.086499
# Name: 2015-05-14, dtype: float64
# country
# AUS   -0.038053
# CAN   -0.022263
# CHE   -0.017808
# DEU   -0.060927
# ESP   -0.020440
# FRA   -0.137401
# GBR   -0.023640
# ITA   -0.060709
# JPN    0.076178
# USA    0.104077
# Name: 2015-05-15, dtype: float64
# country
# AUS   -0.040809
# CAN   -0.021245
# CHE   -0.017227
# DEU   -0.054262
# ESP   -0.023397
# FRA   -0.128672
# GBR   -0.021243
# ITA   -0.054112
# JPN    0.163478
# USA    0.107042
# Name: 2015-05-18, dtype: float64
# country
# AUS   -0.047902
# CAN   -0.026748
# CHE   -0.013679
# DEU   -0.047046
# ESP   -0.022062
# FRA   -0.117563
# GBR   -0.024357
# ITA   -0.058186
# JPN    0.143968
# USA    0.109052
# Name: 2015-05-19, dtype: float64
# country
# AUS   -0.045318
# CAN   -0.022484
# CHE   -0.017162
# DEU   -0.045025
# ESP   -0.028161
# FRA   -0.116658
# GBR   -0.027277
# ITA   -0.059801
# JPN    0.125487
# USA    0.102994
# Name: 2015-05-20, dtype: float64
# country
# AUS   -0.052878
# CAN   -0.018978
# CHE   -0.011124
# DEU   -0.041417
# ESP   -0.032757
# FRA   -0.123355
# GBR   -0.017644
# ITA   -0.063171
# JPN    0.181817
# USA    0.085189
# Name: 2015-05-21, dtype: float64
# country
# AUS   -0.028949
# CAN   -0.023362
# CHE   -0.010496
# DEU   -0.036174
# ESP   -0.034651
# FRA   -0.125164
# GBR   -0.026379
# ITA   -0.066641
# JPN    0.156966
# USA    0.098488
# Name: 2015-05-22, dtype: float64
# country
# AUS   -0.035855
# CAN   -0.028575
# CHE   -0.008872
# DEU   -0.027597
# ESP   -0.029869
# FRA   -0.117691
# GBR   -0.013730
# ITA   -0.071525
# JPN    0.207308
# USA    0.106267
# Name: 2015-05-25, dtype: float64
# country
# AUS   -0.040436
# CAN   -0.014773
# CHE   -0.012156
# DEU   -0.026175
# ESP   -0.046890
# FRA   -0.133479
# GBR   -0.015071
# ITA   -0.087026
# JPN    0.128698
# USA    0.064689
# Name: 2015-05-26, dtype: float64
# country
# AUS   -0.030745
# CAN   -0.013298
# CHE   -0.025425
# DEU   -0.023826
# ESP   -0.047389
# FRA   -0.124929
# GBR   -0.023782
# ITA   -0.083480
# JPN    0.076728
# USA    0.066776
# Name: 2015-05-27, dtype: float64
# country
# AUS   -0.031658
# CAN   -0.024858
# CHE   -0.021094
# DEU   -0.017117
# ESP   -0.042254
# FRA   -0.098326
# GBR   -0.023727
# ITA   -0.070891
# JPN    0.192446
# USA    0.102747
# Name: 2015-05-28, dtype: float64
# country
# AUS   -0.048366
# CAN   -0.001061
# CHE   -0.007123
# DEU   -0.015588
# ESP   -0.050969
# FRA   -0.109574
# GBR   -0.000363
# ITA   -0.095481
# JPN    0.362615
# USA    0.050153
# Name: 2015-05-29, dtype: float64
# country
# AUS   -0.026113
# CAN   -0.005658
# CHE   -0.021665
# DEU   -0.006592
# ESP   -0.071743
# FRA   -0.074418
# GBR   -0.006386
# ITA   -0.104672
# JPN    0.447126
# USA    0.051586
# Name: 2015-06-01, dtype: float64
# country
# AUS   -0.037356
# CAN   -0.009862
# CHE   -0.007679
# DEU   -0.016520
# ESP   -0.054394
# FRA   -0.101435
# GBR   -0.011389
# ITA   -0.073904
# JPN    0.264972
# USA    0.068360
# Name: 2015-06-02, dtype: float64
# country
# AUS   -0.036334
# CAN   -0.001180
# CHE   -0.025681
# DEU   -0.020583
# ESP   -0.036331
# FRA   -0.110381
# GBR   -0.026891
# ITA   -0.054986
# JPN    0.269003
# USA    0.041027
# Name: 2015-06-03, dtype: float64
# country
# AUS   -0.035403
# CAN   -0.014586
# CHE   -0.027079
# DEU   -0.015464
# ESP   -0.061344
# FRA   -0.115758
# GBR   -0.001787
# ITA   -0.069170
# JPN    0.033465
# USA    0.026124
# Name: 2015-06-04, dtype: float64
# country
# AUS   -0.065169
# CAN   -0.011516
# CHE   -0.015617
# DEU   -0.011102
# ESP   -0.066583
# FRA   -0.100980
# GBR   -0.004339
# ITA   -0.070783
# JPN    0.008484
# USA    0.044629
# Name: 2015-06-05, dtype: float64
# country
# AUS   -0.022671
# CAN   -0.045388
# CHE   -0.044006
# DEU   -0.009014
# ESP   -0.047675
# FRA   -0.083236
# GBR   -0.040824
# ITA   -0.047499
# JPN    0.080313
# USA    0.053146
# Name: 2015-06-08, dtype: float64
# country
# AUS   -0.084485
# CAN   -0.008341
# CHE   -0.042203
# DEU   -0.007627
# ESP   -0.050011
# FRA   -0.080007
# GBR   -0.008638
# ITA   -0.038123
# JPN    0.270222
# USA    0.029444
# Name: 2015-06-09, dtype: float64
# country
# AUS   -0.046025
# CAN   -0.003887
# CHE   -0.027286
# DEU   -0.008666
# ESP   -0.062035
# FRA   -0.096654
# GBR   -0.009577
# ITA   -0.036304
# JPN    0.090728
# USA    0.036106
# Name: 2015-06-10, dtype: float64
# country
# AUS   -0.024140
# CAN   -0.061525
# CHE   -0.007999
# DEU   -0.004540
# ESP   -0.044219
# FRA   -0.072271
# GBR   -0.080195
# ITA   -0.018982
# JPN    0.137455
# USA    0.079228
# Name: 2015-06-11, dtype: float64
# country
# AUS   -0.020787
# CAN   -0.053133
# CHE   -0.010743
# DEU   -0.001022
# ESP   -0.072365
# FRA   -0.049871
# GBR   -0.150279
# ITA   -0.035696
# JPN    0.093956
# USA    0.036922
# Name: 2015-06-12, dtype: float64
# country
# AUS   -0.014275
# CAN   -0.069056
# CHE   -0.015773
# DEU   -0.002433
# ESP   -0.049822
# FRA   -0.034237
# GBR   -0.127157
# ITA   -0.021763
# JPN    0.180184
# USA    0.103267
# Name: 2015-06-15, dtype: float64
# country
# AUS   -0.020186
# CAN   -0.104819
# CHE   -0.005570
# DEU   -0.002049
# ESP   -0.037298
# FRA   -0.033580
# GBR   -0.123398
# ITA   -0.013055
# JPN    0.229402
# USA    0.100152
# Name: 2015-06-16, dtype: float64
# country
# AUS   -0.015140
# CAN   -0.097032
# CHE   -0.011528
# DEU   -0.005117
# ESP   -0.028781
# FRA   -0.011432
# GBR   -0.136716
# ITA   -0.008956
# JPN    0.320728
# USA    0.126050
# Name: 2015-06-17, dtype: float64
# country
# AUS   -0.078105
# CAN   -0.060458
# CHE   -0.012685
# DEU   -0.002976
# ESP   -0.020791
# FRA   -0.011719
# GBR   -0.124098
# ITA   -0.008785
# JPN    0.669746
# USA    0.061803
# Name: 2015-06-18, dtype: float64
# country
# AUS   -0.006335
# CAN   -0.092572
# CHE   -0.017721
# DEU   -0.002109
# ESP   -0.018801
# FRA   -0.015742
# GBR   -0.123017
# ITA   -0.015210
# JPN    0.567890
# USA    0.092483
# Name: 2015-06-19, dtype: float64
# country
# AUS   -0.025553
# CAN   -0.061659
# CHE   -0.041214
# DEU   -0.004154
# ESP   -0.018131
# FRA   -0.032455
# GBR   -0.063278
# ITA   -0.010423
# JPN    0.449808
# USA    0.033589
# Name: 2015-06-22, dtype: float64
# country
# AUS   -0.045710
# CAN   -0.003367
# CHE   -0.057916
# DEU   -0.002291
# ESP   -0.015157
# FRA   -0.034157
# GBR   -0.017005
# ITA   -0.019319
# JPN    0.180038
# USA    0.027108
# Name: 2015-06-23, dtype: float64
# country
# AUS   -0.116873
# CAN   -0.000163
# CHE   -0.033921
# DEU    0.001217
# ESP   -0.015312
# FRA   -0.024197
# GBR   -0.018628
# ITA   -0.022313
# JPN    0.136495
# USA    0.018652
# Name: 2015-06-24, dtype: float64
# country
# AUS   -0.097021
# CAN   -0.011202
# CHE   -0.034482
# DEU    0.006131
# ESP   -0.011497
# FRA   -0.016308
# GBR   -0.044186
# ITA   -0.022978
# JPN    0.142582
# USA    0.001726
# Name: 2015-06-25, dtype: float64
# country
# AUS   -0.021722
# CAN   -0.022840
# CHE   -0.050101
# DEU    0.016812
# ESP   -0.012434
# FRA   -0.002607
# GBR   -0.056576
# ITA   -0.020399
# JPN    0.107824
# USA    0.035569
# Name: 2015-06-26, dtype: float64
# country
# AUS   -0.020061
# CAN   -0.056810
# CHE   -0.040980
# DEU    0.015480
# ESP   -0.011691
# FRA    0.009004
# GBR   -0.018132
# ITA   -0.020553
# JPN    0.260030
# USA    0.038098
# Name: 2015-06-29, dtype: float64
# country
# AUS   -0.086528
# CAN   -0.114979
# CHE   -0.027867
# DEU    0.008291
# ESP   -0.005725
# FRA    0.012440
# GBR   -0.122785
# ITA   -0.013223
# JPN    0.235810
# USA    0.031810
# Name: 2015-06-30, dtype: float64
# country
# AUS   -0.104252
# CAN   -0.140717
# CHE   -0.020464
# DEU    0.003117
# ESP   -0.003714
# FRA    0.014430
# GBR   -0.166851
# ITA   -0.010226
# JPN    0.245723
# USA    0.041853
# Name: 2015-07-01, dtype: float64
# country
# AUS   -0.105212
# CAN   -0.093582
# CHE   -0.030859
# DEU    0.008787
# ESP   -0.004839
# FRA    0.024877
# GBR   -0.110863
# ITA   -0.009566
# JPN    0.190615
# USA    0.036571
# Name: 2015-07-02, dtype: float64
# country
# AUS   -0.057262
# CAN   -0.180765
# CHE   -0.000985
# DEU    0.000783
# ESP   -0.002693
# FRA    0.022964
# GBR   -0.267287
# ITA   -0.004858
# JPN    0.192315
# USA    0.088757
# Name: 2015-07-03, dtype: float64
# country
# AUS   -0.010573
# CAN   -0.189514
# CHE   -0.030873
# DEU    0.007487
# ESP   -0.000655
# FRA    0.016739
# GBR   -0.242806
# ITA   -0.001851
# JPN    0.398114
# USA    0.092458
# Name: 2015-07-06, dtype: float64
# country
# AUS   -0.036281
# CAN   -0.189046
# CHE   -0.050009
# DEU    0.016022
# ESP   -0.005170
# FRA    0.009191
# GBR   -0.265202
# ITA   -0.000754
# JPN    0.089517
# USA    0.063161
# Name: 2015-07-07, dtype: float64
# country
# AUS   -0.022529
# CAN   -0.238011
# CHE   -0.022877
# DEU    0.012955
# ESP   -0.005587
# FRA    0.001640
# GBR   -0.176259
# ITA   -0.000006
# JPN    0.352530
# USA    0.101878
# Name: 2015-07-08, dtype: float64
# country
# AUS   -0.022628
# CAN   -0.267152
# CHE   -0.001084
# DEU    0.004945
# ESP   -0.003651
# FRA    0.023772
# GBR   -0.131371
# ITA    0.000864
# JPN    0.485867
# USA    0.063127
# Name: 2015-07-09, dtype: float64
# country
# AUS   -0.040822
# CAN   -0.102054
# CHE   -0.049615
# DEU    0.030322
# ESP   -0.000469
# FRA    0.062828
# GBR   -0.101857
# ITA    0.001652
# JPN    0.263951
# USA    0.014937
# Name: 2015-07-10, dtype: float64
# country
# AUS   -0.027838
# CAN   -0.048142
# CHE   -0.067063
# DEU    0.041007
# ESP   -0.000917
# FRA    0.071852
# GBR   -0.155995
# ITA    0.001742
# JPN    0.115878
# USA    0.028212
# Name: 2015-07-13, dtype: float64
# country
# AUS   -0.047013
# CAN   -0.057968
# CHE   -0.058909
# DEU    0.044676
# ESP   -0.002145
# FRA    0.075588
# GBR   -0.169310
# ITA    0.001855
# JPN    0.085155
# USA    0.017840
# Name: 2015-07-14, dtype: float64
# country
# AUS   -0.039568
# CAN   -0.056725
# CHE   -0.053857
# DEU    0.046656
# ESP   -0.004257
# FRA    0.094130
# GBR   -0.128807
# ITA    0.004680
# JPN    0.051182
# USA    0.016523
# Name: 2015-07-15, dtype: float64
# country
# AUS   -0.064156
# CAN   -0.102176
# CHE   -0.049365
# DEU    0.044118
# ESP   -0.008466
# FRA    0.094254
# GBR   -0.083703
# ITA    0.004319
# JPN    0.087805
# USA    0.007993
# Name: 2015-07-16, dtype: float64
# country
# AUS   -0.048236
# CAN   -0.028137
# CHE   -0.043980
# DEU    0.050434
# ESP   -0.008527
# FRA    0.093622
# GBR   -0.122156
# ITA    0.003769
# JPN    0.119790
# USA    0.046912
# Name: 2015-07-17, dtype: float64
# country
# AUS   -0.034622
# CAN   -0.155417
# CHE   -0.049580
# DEU    0.032817
# ESP   -0.014478
# FRA    0.071181
# GBR   -0.105795
# ITA    0.006083
# JPN    0.131402
# USA    0.026881
# Name: 2015-07-20, dtype: float64
# country
# AUS   -0.026910
# CAN   -0.215986
# CHE   -0.037098
# DEU    0.035324
# ESP   -0.018171
# FRA    0.093218
# GBR   -0.104098
# ITA    0.010125
# JPN    0.012395
# USA    0.005292
# Name: 2015-07-21, dtype: float64
# country
# AUS   -0.038446
# CAN   -0.375914
# CHE   -0.033292
# DEU    0.025798
# ESP   -0.014052
# FRA    0.065893
# GBR   -0.092258
# ITA    0.007023
# JPN    0.142216
# USA    0.000390
# Name: 2015-07-22, dtype: float64
# country
# AUS   -0.090631
# CAN   -0.456948
# CHE   -0.029178
# DEU    0.002735
# ESP   -0.007419
# FRA    0.019433
# GBR   -0.163169
# ITA    0.001790
# JPN    0.114394
# USA    0.036594
# Name: 2015-07-23, dtype: float64
# country
# AUS   -0.036228
# CAN   -0.375129
# CHE   -0.003434
# DEU    0.037461
# ESP   -0.004389
# FRA    0.048566
# GBR   -0.206401
# ITA    0.005776
# JPN    0.066063
# USA    0.062668
# Name: 2015-07-24, dtype: float64
# country
# AUS   -0.031815
# CAN   -0.469119
# CHE   -0.020801
# DEU    0.006478
# ESP   -0.010803
# FRA    0.007408
# GBR   -0.181736
# ITA    0.012411
# JPN    0.088454
# USA    0.026083
# Name: 2015-07-27, dtype: float64
# country
# AUS   -0.056708
# CAN   -0.358683
# CHE   -0.044847
# DEU    0.047012
# ESP   -0.001021
# FRA    0.079805
# GBR   -0.002683
# ITA    0.000742
# JPN    0.179000
# USA    0.020550
# Name: 2015-07-28, dtype: float64
# country
# AUS   -0.088671
# CAN   -0.218443
# CHE   -0.046386
# DEU    0.030008
# ESP   -0.002553
# FRA    0.080448
# GBR   -0.057271
# ITA    0.000987
# JPN    0.191772
# USA    0.016236
# Name: 2015-07-29, dtype: float64
# country
# AUS   -0.096725
# CAN   -0.316047
# CHE   -0.029994
# DEU    0.016652
# ESP   -0.003182
# FRA    0.055153
# GBR   -0.121315
# ITA    0.002194
# JPN    0.233294
# USA    0.010948
# Name: 2015-07-30, dtype: float64
# country
# AUS   -0.044731
# CAN   -0.163451
# CHE   -0.026106
# DEU    0.056162
# ESP   -0.004431
# FRA    0.101212
# GBR   -0.140141
# ITA    0.006222
# JPN    0.084137
# USA    0.020526
# Name: 2015-07-31, dtype: float64
# country
# AUS   -0.024051
# CAN   -0.010857
# CHE   -0.019579
# DEU    0.082229
# ESP   -0.003872
# FRA    0.127444
# GBR   -0.172826
# ITA    0.006676
# JPN    0.076071
# USA    0.043184
# Name: 2015-08-03, dtype: float64
# country
# AUS   -0.012477
# CAN   -0.011917
# CHE   -0.018265
# DEU    0.095055
# ESP   -0.007686
# FRA    0.131815
# GBR   -0.205196
# ITA    0.005756
# JPN    0.015175
# USA    0.030001
# Name: 2015-08-04, dtype: float64
# country
# AUS   -0.054506
# CAN   -0.053222
# CHE   -0.011851
# DEU    0.078950
# ESP   -0.010807
# FRA    0.102810
# GBR   -0.121272
# ITA    0.006142
# JPN    0.139950
# USA    0.043319
# Name: 2015-08-05, dtype: float64
# country
# AUS   -0.024465
# CAN   -0.027809
# CHE   -0.011767
# DEU    0.094397
# ESP   -0.012361
# FRA    0.116988
# GBR   -0.117593
# ITA    0.007527
# JPN    0.199224
# USA    0.025108
# Name: 2015-08-06, dtype: float64
# country
# AUS   -0.077728
# CAN   -0.136170
# CHE   -0.006904
# DEU    0.056696
# ESP   -0.016051
# FRA    0.094211
# GBR   -0.022066
# ITA    0.011838
# JPN    0.360804
# USA    0.001895
# Name: 2015-08-07, dtype: float64
# country
# AUS   -0.012774
# CAN   -0.069107
# CHE   -0.007399
# DEU    0.096502
# ESP   -0.011817
# FRA    0.126239
# GBR   -0.057111
# ITA    0.014096
# JPN    0.358292
# USA    0.003142
# Name: 2015-08-10, dtype: float64
# country
# AUS   -0.123444
# CAN   -0.241280
# CHE   -0.004539
# DEU    0.022353
# ESP   -0.008525
# FRA    0.046965
# GBR   -0.138171
# ITA    0.014013
# JPN    0.193065
# USA    0.029143
# Name: 2015-08-11, dtype: float64
# country
# AUS   -0.312023
# CAN   -0.313659
# CHE   -0.003576
# DEU    0.002722
# ESP   -0.001306
# FRA    0.011357
# GBR   -0.214578
# ITA    0.003421
# JPN    0.015779
# USA    0.018569
# Name: 2015-08-12, dtype: float64
# country
# AUS   -0.353581
# CAN   -0.244588
# CHE   -0.001029
# DEU    0.003784
# ESP   -0.002991
# FRA    0.038454
# GBR   -0.109843
# ITA    0.014140
# JPN    0.016864
# USA    0.018952
# Name: 2015-08-13, dtype: float64
# country
# AUS   -0.264553
# CAN   -0.247910
# CHE   -0.006121
# DEU    0.007930
# ESP   -0.003762
# FRA    0.032358
# GBR   -0.126356
# ITA    0.011320
# JPN    0.032867
# USA    0.038828
# Name: 2015-08-14, dtype: float64
# country
# AUS   -0.265437
# CAN   -0.126654
# CHE   -0.007544
# DEU    0.031939
# ESP   -0.003209
# FRA    0.104513
# GBR   -0.123716
# ITA    0.013412
# JPN    0.016021
# USA    0.017281
# Name: 2015-08-17, dtype: float64
# country
# AUS   -0.327015
# CAN   -0.180020
# CHE   -0.008643
# DEU    0.021065
# ESP   -0.003175
# FRA    0.002488
# GBR   -0.197931
# ITA    0.005107
# JPN    0.068080
# USA    0.021075
# Name: 2015-08-18, dtype: float64
# country
# AUS   -0.263039
# CAN   -0.287221
# CHE   -0.006450
# DEU    0.010352
# ESP   -0.001179
# FRA    0.039942
# GBR   -0.114580
# ITA    0.015997
# JPN    0.059888
# USA    0.043239
# Name: 2015-08-19, dtype: float64
# country
# AUS   -0.198949
# CAN   -0.278209
# CHE   -0.009462
# DEU    0.040086
# ESP   -0.000817
# FRA    0.018689
# GBR   -0.141442
# ITA    0.003548
# JPN    0.155946
# USA    0.046348
# Name: 2015-08-20, dtype: float64
# country
# AUS   -0.213207
# CAN   -0.233026
# CHE   -0.009573
# DEU    0.036916
# ESP   -0.000075
# FRA    0.011705
# GBR   -0.129591
# ITA    0.003965
# JPN    0.264423
# USA    0.045271
# Name: 2015-08-21, dtype: float64
# country
# AUS   -0.194066
# CAN   -0.172097
# CHE   -0.011474
# DEU    0.039317
# ESP   -0.000097
# FRA    0.036074
# GBR   -0.156311
# ITA    0.005436
# JPN    0.214871
# USA    0.041393
# Name: 2015-08-24, dtype: float64
# country
# AUS   -0.195352
# CAN   -0.204469
# CHE   -0.011607
# DEU    0.000796
# ESP    0.000173
# FRA    0.014192
# GBR   -0.141120
# ITA    0.003390
# JPN    0.324205
# USA    0.055603
# Name: 2015-08-25, dtype: float64
# country
# AUS   -0.134978
# CAN   -0.164701
# CHE   -0.023858
# DEU    0.031314
# ESP    0.000765
# FRA    0.040255
# GBR   -0.168381
# ITA    0.001317
# JPN    0.229895
# USA    0.040460
# Name: 2015-08-26, dtype: float64
# country
# AUS   -0.214650
# CAN   -0.044147
# CHE   -0.026487
# DEU    0.031397
# ESP    0.004097
# FRA    0.035268
# GBR   -0.104439
# ITA    0.018183
# JPN    0.298863
# USA    0.025248
# Name: 2015-08-27, dtype: float64
# country
# AUS   -0.210963
# CAN   -0.044588
# CHE   -0.040230
# DEU    0.025152
# ESP    0.005672
# FRA    0.021516
# GBR   -0.073886
# ITA    0.016992
# JPN    0.264484
# USA    0.029750
# Name: 2015-08-28, dtype: float64
# country
# AUS   -0.256589
# CAN   -0.085554
# CHE   -0.034465
# DEU    0.005317
# ESP    0.001903
# FRA    0.041940
# GBR   -0.125671
# ITA    0.007010
# JPN    0.290092
# USA    0.030473
# Name: 2015-08-31, dtype: float64
# country
# AUS   -0.219426
# CAN   -0.126614
# CHE   -0.030655
# DEU    0.025797
# ESP    0.001740
# FRA    0.039837
# GBR   -0.148209
# ITA    0.005514
# JPN    0.263627
# USA    0.032463
# Name: 2015-09-01, dtype: float64
# country
# AUS   -0.171742
# CAN   -0.129955
# CHE   -0.026690
# DEU    0.047668
# ESP    0.007288
# FRA    0.062138
# GBR   -0.141398
# ITA    0.014058
# JPN    0.243598
# USA    0.025407
# Name: 2015-09-02, dtype: float64
# country
# AUS   -0.180338
# CAN   -0.099734
# CHE   -0.026585
# DEU    0.058582
# ESP    0.007778
# FRA    0.072832
# GBR   -0.143625
# ITA    0.019383
# JPN    0.253143
# USA    0.020641
# Name: 2015-09-03, dtype: float64
# country
# AUS   -0.130027
# CAN   -0.105344
# CHE   -0.023723
# DEU    0.068851
# ESP    0.009114
# FRA    0.090213
# GBR   -0.157609
# ITA    0.030238
# JPN    0.227823
# USA    0.020890
# Name: 2015-09-04, dtype: float64
# country
# AUS   -0.148193
# CAN   -0.113927
# CHE   -0.023022
# DEU    0.068267
# ESP    0.007243
# FRA    0.084815
# GBR   -0.163061
# ITA    0.025012
# JPN    0.238744
# USA    0.021365
# Name: 2015-09-07, dtype: float64
# country
# AUS   -0.152661
# CAN   -0.096944
# CHE   -0.026462
# DEU    0.053242
# ESP    0.010468
# FRA    0.072857
# GBR   -0.145624
# ITA    0.024529
# JPN    0.335938
# USA    0.017958
# Name: 2015-09-08, dtype: float64
# country
# AUS   -0.122358
# CAN   -0.127279
# CHE   -0.025953
# DEU    0.054730
# ESP    0.010250
# FRA    0.069013
# GBR   -0.135252
# ITA    0.025302
# JPN    0.282844
# USA    0.026341
# Name: 2015-09-09, dtype: float64
# country
# AUS   -0.122195
# CAN   -0.105353
# CHE   -0.026493
# DEU    0.054520
# ESP    0.014653
# FRA    0.094375
# GBR   -0.145080
# ITA    0.032815
# JPN    0.263357
# USA    0.019829
# Name: 2015-09-10, dtype: float64
# country
# AUS   -0.127192
# CAN   -0.114814
# CHE   -0.017771
# DEU    0.061500
# ESP    0.020858
# FRA    0.101181
# GBR   -0.141427
# ITA    0.040927
# JPN    0.232745
# USA    0.018512
# Name: 2015-09-11, dtype: float64
# country
# AUS   -0.094026
# CAN   -0.127208
# CHE   -0.017601
# DEU    0.065335
# ESP    0.023001
# FRA    0.115209
# GBR   -0.137242
# ITA    0.038807
# JPN    0.223997
# USA    0.018138
# Name: 2015-09-14, dtype: float64
# country
# AUS   -0.123716
# CAN   -0.098713
# CHE   -0.011780
# DEU    0.050118
# ESP    0.027576
# FRA    0.104993
# GBR   -0.139458
# ITA    0.040839
# JPN    0.302821
# USA    0.015401
# Name: 2015-09-15, dtype: float64
# country
# AUS   -0.102145
# CAN   -0.016608
# CHE   -0.007617
# DEU    0.030099
# ESP    0.033537
# FRA    0.117542
# GBR   -0.106542
# ITA    0.053366
# JPN    0.436568
# USA    0.015901
# Name: 2015-09-16, dtype: float64
# country
# AUS   -0.094473
# CAN   -0.122685
# CHE   -0.001232
# DEU    0.017594
# ESP    0.033275
# FRA    0.097000
# GBR   -0.062808
# ITA    0.045376
# JPN    0.484010
# USA    0.017645
# Name: 2015-09-17, dtype: float64
# country
# AUS   -0.102756
# CAN   -0.037230
# CHE   -0.001218
# DEU    0.046405
# ESP    0.043198
# FRA    0.139835
# GBR   -0.100721
# ITA    0.065028
# JPN    0.334448
# USA    0.013822
# Name: 2015-09-18, dtype: float64
# country
# AUS   -0.149421
# CAN   -0.313817
# CHE   -0.027708
# DEU    0.032843
# ESP    0.003497
# FRA    0.004100
# GBR   -0.159232
# ITA    0.037464
# JPN    0.230139
# USA    0.011209
# Name: 2015-09-21, dtype: float64
# country
# AUS   -0.072013
# CAN   -0.094035
# CHE   -0.009817
# DEU    0.147338
# ESP    0.041979
# FRA    0.178864
# GBR   -0.097748
# ITA    0.064396
# JPN    0.086700
# USA    0.004376
# Name: 2015-09-22, dtype: float64
# country
# AUS   -0.111948
# CAN   -0.016587
# CHE   -0.002690
# DEU    0.120270
# ESP    0.048209
# FRA    0.135936
# GBR   -0.040538
# ITA    0.060349
# JPN    0.254675
# USA    0.013159
# Name: 2015-09-23, dtype: float64
# country
# AUS   -0.060924
# CAN   -0.089517
# CHE   -0.009087
# DEU    0.103200
# ESP    0.028651
# FRA    0.126729
# GBR   -0.149542
# ITA    0.062558
# JPN    0.163891
# USA    0.016877
# Name: 2015-09-24, dtype: float64
# country
# AUS   -0.084174
# CAN   -0.038251
# CHE   -0.007454
# DEU    0.100118
# ESP    0.029717
# FRA    0.113649
# GBR   -0.095706
# ITA    0.039955
# JPN    0.326173
# USA    0.017058
# Name: 2015-09-25, dtype: float64
# country
# AUS   -0.030450
# CAN   -0.138216
# CHE   -0.008055
# DEU    0.095844
# ESP    0.032162
# FRA    0.107500
# GBR   -0.130590
# ITA    0.056933
# JPN    0.185607
# USA    0.019201
# Name: 2015-09-28, dtype: float64
# country
# AUS   -0.002741
# CAN   -0.068317
# CHE   -0.008955
# DEU    0.108034
# ESP    0.033813
# FRA    0.127923
# GBR   -0.099545
# ITA    0.074214
# JPN    0.248892
# USA    0.014466
# Name: 2015-09-29, dtype: float64
# country
# AUS   -0.060016
# CAN   -0.001887
# CHE   -0.005452
# DEU    0.115657
# ESP    0.036183
# FRA    0.142124
# GBR   -0.021953
# ITA    0.087462
# JPN    0.225421
# USA    0.019572
# Name: 2015-09-30, dtype: float64
# country
# AUS   -0.177346
# CAN   -0.058211
# CHE   -0.005867
# DEU    0.112629
# ESP    0.028629
# FRA    0.124693
# GBR   -0.061895
# ITA    0.079090
# JPN    0.194906
# USA    0.005020
# Name: 2015-10-01, dtype: float64
# country
# AUS   -0.291970
# CAN   -0.158981
# CHE   -0.002167
# DEU    0.028693
# ESP    0.018499
# FRA    0.007733
# GBR   -0.491762
# ITA    0.040142
# JPN    0.032111
# USA    0.007390
# Name: 2015-10-02, dtype: float64
# country
# AUS   -0.218630
# CAN   -0.226366
# CHE   -0.001910
# DEU    0.015152
# ESP    0.018899
# FRA    0.025021
# GBR   -0.462689
# ITA    0.018260
# JPN    0.012553
# USA    0.021529
# Name: 2015-10-05, dtype: float64
# country
# AUS   -0.236986
# CAN   -0.210632
# CHE   -0.000485
# DEU    0.035250
# ESP    0.003949
# FRA    0.070515
# GBR   -0.437201
# ITA    0.053304
# JPN    0.108698
# USA    0.000421
# Name: 2015-10-06, dtype: float64
# country
# AUS   -0.194638
# CAN   -0.315213
# CHE   -0.000814
# DEU    0.042606
# ESP    0.004726
# FRA    0.072118
# GBR   -0.292701
# ITA    0.043544
# JPN    0.039758
# USA    0.020109
# Name: 2015-10-07, dtype: float64
# country
# AUS   -0.179666
# CAN   -0.259926
# CHE   -0.004063
# DEU    0.045456
# ESP    0.014523
# FRA    0.092486
# GBR   -0.272833
# ITA    0.048132
# JPN    0.049990
# USA    0.014804
# Name: 2015-10-08, dtype: float64
# country
# AUS   -0.161606
# CAN   -0.215184
# CHE   -0.006397
# DEU    0.052183
# ESP    0.015982
# FRA    0.100764
# GBR   -0.227734
# ITA    0.057740
# JPN    0.098426
# USA    0.014131
# Name: 2015-10-09, dtype: float64
# country
# AUS   -0.131665
# CAN   -0.236494
# CHE   -0.008956
# DEU    0.056292
# ESP    0.013838
# FRA    0.106186
# GBR   -0.210242
# ITA    0.050440
# JPN    0.108668
# USA    0.017775
# Name: 2015-10-12, dtype: float64
# country
# AUS   -0.188245
# CAN   -0.198457
# CHE   -0.004248
# DEU    0.045521
# ESP    0.010489
# FRA    0.095354
# GBR   -0.246860
# ITA    0.043079
# JPN    0.119566
# USA    0.017989
# Name: 2015-10-13, dtype: float64
# country
# AUS   -0.136239
# CAN   -0.274037
# CHE   -0.006578
# DEU    0.036754
# ESP    0.008182
# FRA    0.090927
# GBR   -0.232965
# ITA    0.037427
# JPN    0.153429
# USA    0.021758
# Name: 2015-10-14, dtype: float64
# country
# AUS   -0.049161
# CAN   -0.241078
# CHE   -0.009981
# DEU    0.058981
# ESP    0.006995
# FRA    0.119400
# GBR   -0.238181
# ITA    0.053404
# JPN    0.086679
# USA    0.037242
# Name: 2015-10-15, dtype: float64
# country
# AUS   -0.079638
# CAN   -0.186216
# CHE   -0.019748
# DEU    0.065774
# ESP    0.008045
# FRA    0.114568
# GBR   -0.201202
# ITA    0.048251
# JPN    0.130887
# USA    0.035423
# Name: 2015-10-16, dtype: float64
# country
# AUS   -0.139723
# CAN   -0.154882
# CHE   -0.007279
# DEU    0.062695
# ESP    0.004896
# FRA    0.092902
# GBR   -0.197731
# ITA    0.038649
# JPN    0.204617
# USA    0.036947
# Name: 2015-10-19, dtype: float64
# country
# AUS   -0.070015
# CAN   -0.176459
# CHE   -0.022465
# DEU    0.092766
# ESP    0.003297
# FRA    0.122327
# GBR   -0.201091
# ITA    0.040883
# JPN    0.117489
# USA    0.037998
# Name: 2015-10-20, dtype: float64
# country
# AUS   -0.130461
# CAN   -0.147803
# CHE   -0.010755
# DEU    0.090787
# ESP    0.001573
# FRA    0.111092
# GBR   -0.178575
# ITA    0.031848
# JPN    0.206930
# USA    0.031820
# Name: 2015-10-21, dtype: float64
# country
# AUS   -0.103135
# CAN   -0.175048
# CHE   -0.021154
# DEU    0.094015
# ESP   -0.000274
# FRA    0.117850
# GBR   -0.163733
# ITA    0.035889
# JPN    0.159292
# USA    0.042770
# Name: 2015-10-22, dtype: float64
# country
# AUS   -0.127674
# CAN   -0.160101
# CHE   -0.011601
# DEU    0.090255
# ESP   -0.001141
# FRA    0.098688
# GBR   -0.162384
# ITA    0.013572
# JPN    0.255617
# USA    0.046842
# Name: 2015-10-23, dtype: float64
# country
# AUS   -0.050279
# CAN   -0.166257
# CHE   -0.022536
# DEU    0.095196
# ESP   -0.003678
# FRA    0.111109
# GBR   -0.154393
# ITA    0.026099
# JPN    0.205439
# USA    0.054863
# Name: 2015-10-26, dtype: float64
# country
# AUS   -0.097532
# CAN   -0.135317
# CHE   -0.015222
# DEU    0.088919
# ESP   -0.005038
# FRA    0.102236
# GBR   -0.140149
# ITA    0.023990
# JPN    0.241119
# USA    0.056235
# Name: 2015-10-27, dtype: float64
# country
# AUS   -0.096085
# CAN   -0.150596
# CHE   -0.006218
# DEU    0.085999
# ESP   -0.004939
# FRA    0.113955
# GBR   -0.136715
# ITA    0.013343
# JPN    0.242398
# USA    0.069860
# Name: 2015-10-28, dtype: float64
# country
# AUS   -0.053504
# CAN   -0.147518
# CHE   -0.021031
# DEU    0.113556
# ESP   -0.007956
# FRA    0.141051
# GBR   -0.120649
# ITA    0.021413
# JPN    0.192090
# USA    0.058534
# Name: 2015-10-29, dtype: float64
# country
# AUS   -0.017305
# CAN   -0.152241
# CHE   -0.031859
# DEU    0.136267
# ESP   -0.008518
# FRA    0.161266
# GBR   -0.110041
# ITA    0.013764
# JPN    0.171647
# USA    0.065010
# Name: 2015-10-30, dtype: float64
# country
# AUS   -0.022277
# CAN   -0.181796
# CHE   -0.002812
# DEU    0.158654
# ESP   -0.010258
# FRA    0.185458
# GBR   -0.107485
# ITA    0.009221
# JPN    0.060811
# USA    0.082627
# Name: 2015-11-02, dtype: float64
# country
# AUS   -0.024382
# CAN   -0.220173
# CHE   -0.005095
# DEU    0.142305
# ESP   -0.009317
# FRA    0.155435
# GBR   -0.105894
# ITA    0.006327
# JPN    0.057098
# USA    0.104300
# Name: 2015-11-03, dtype: float64
# country
# AUS   -0.107944
# CAN   -0.129943
# CHE   -0.008745
# DEU    0.169432
# ESP   -0.007827
# FRA    0.220369
# GBR   -0.113188
# ITA    0.008042
# JPN    0.031445
# USA    0.062717
# Name: 2015-11-04, dtype: float64
# country
# AUS   -0.134564
# CAN   -0.022970
# CHE   -0.078764
# DEU    0.193144
# ESP   -0.002790
# FRA    0.234492
# GBR   -0.042827
# ITA    0.016456
# JPN    0.092970
# USA    0.076666
# Name: 2015-11-05, dtype: float64
# country
# AUS   -0.207781
# CAN   -0.005338
# CHE   -0.118934
# DEU    0.209118
# ESP   -0.006747
# FRA    0.197300
# GBR   -0.014151
# ITA    0.001101
# JPN    0.171933
# USA    0.054516
# Name: 2015-11-06, dtype: float64
# country
# AUS   -0.348356
# CAN   -0.071845
# CHE   -0.140315
# DEU    0.133160
# ESP   -0.007436
# FRA    0.144486
# GBR   -0.009073
# ITA    0.005392
# JPN    0.138565
# USA    0.036661
# Name: 2015-11-09, dtype: float64
# country
# AUS   -0.333136
# CAN   -0.021196
# CHE   -0.230567
# DEU    0.115418
# ESP   -0.008896
# FRA    0.124337
# GBR   -0.046721
# ITA    0.005846
# JPN    0.087269
# USA    0.014901
# Name: 2015-11-10, dtype: float64
# country
# AUS   -0.213079
# CAN   -0.191225
# CHE   -0.144314
# DEU    0.154278
# ESP   -0.008154
# FRA    0.162056
# GBR   -0.007061
# ITA    0.005890
# JPN    0.178142
# USA    0.002356
# Name: 2015-11-11, dtype: float64
# country
# AUS   -0.014678
# CAN   -0.212666
# CHE   -0.148865
# DEU    0.013521
# ESP   -0.003162
# FRA    0.070504
# GBR   -0.115525
# ITA    0.029363
# JPN    0.168814
# USA    0.077447
# Name: 2015-11-12, dtype: float64
# country
# AUS   -0.115403
# CAN   -0.164701
# CHE   -0.150444
# DEU    0.012742
# ESP   -0.003833
# FRA    0.055644
# GBR   -0.108444
# ITA    0.018948
# JPN    0.208027
# USA    0.066152
# Name: 2015-11-13, dtype: float64
# country
# AUS   -0.179631
# CAN   -0.125881
# CHE   -0.132608
# DEU    0.028527
# ESP   -0.001993
# FRA    0.005777
# GBR   -0.088732
# ITA    0.023240
# JPN    0.341269
# USA    0.043605
# Name: 2015-11-16, dtype: float64
# country
# AUS   -0.026300
# CAN   -0.276367
# CHE   -0.141237
# DEU    0.008940
# ESP   -0.001311
# FRA    0.000476
# GBR   -0.119800
# ITA    0.019041
# JPN    0.224117
# USA    0.080977
# Name: 2015-11-17, dtype: float64
# country
# AUS   -0.066484
# CAN   -0.046131
# CHE   -0.068050
# DEU    0.027465
# ESP   -0.000822
# FRA    0.041872
# GBR   -0.098457
# ITA    0.020817
# JPN    0.621246
# USA    0.022238
# Name: 2015-11-18, dtype: float64
# country
# AUS   -0.131830
# CAN   -0.244143
# CHE   -0.055499
# DEU    0.016990
# ESP   -0.002324
# FRA    0.030138
# GBR   -0.078968
# ITA    0.012995
# JPN    0.347067
# USA    0.048651
# Name: 2015-11-19, dtype: float64
# country
# AUS   -0.193975
# CAN   -0.217985
# CHE   -0.063491
# DEU    0.000393
# ESP   -0.001398
# FRA    0.025269
# GBR   -0.093958
# ITA    0.004234
# JPN    0.377366
# USA    0.028750
# Name: 2015-11-20, dtype: float64
# country
# AUS   -0.311666
# CAN   -0.107084
# CHE   -0.087486
# DEU    0.029187
# ESP   -0.000171
# FRA    0.015323
# GBR   -0.093408
# ITA    0.006239
# JPN    0.390941
# USA    0.013844
# Name: 2015-11-23, dtype: float64
# country
# AUS   -0.272108
# CAN   -0.017324
# CHE   -0.095454
# DEU    0.112121
# ESP   -0.000247
# FRA    0.099296
# GBR   -0.084244
# ITA    0.000087
# JPN    0.348641
# USA    0.014223
# Name: 2015-11-24, dtype: float64
# country
# AUS   -0.253992
# CAN   -0.098120
# CHE   -0.084269
# DEU    0.026651
# ESP   -0.000029
# FRA    0.045167
# GBR   -0.034579
# ITA    0.037422
# JPN    0.433757
# USA    0.009276
# Name: 2015-11-25, dtype: float64
# country
# AUS   -0.300736
# CAN   -0.152466
# CHE   -0.085392
# DEU    0.064379
# ESP   -0.001054
# FRA    0.064478
# GBR   -0.031730
# ITA    0.010985
# JPN    0.259687
# USA    0.020284
# Name: 2015-11-26, dtype: float64
# country
# AUS   -0.409744
# CAN   -0.002001
# CHE   -0.107160
# DEU    0.111125
# ESP   -0.001171
# FRA    0.127190
# GBR   -0.018474
# ITA    0.005402
# JPN    0.217726
# USA    0.006394
# Name: 2015-11-27, dtype: float64
# country
# AUS   -0.506204
# CAN   -0.138857
# CHE   -0.046295
# DEU    0.049950
# ESP   -0.003984
# FRA    0.038021
# GBR   -0.031690
# ITA    0.030973
# JPN    0.053811
# USA    0.010841
# Name: 2015-11-30, dtype: float64
# country
# AUS   -0.491177
# CAN   -0.021972
# CHE   -0.074794
# DEU    0.125895
# ESP   -0.002977
# FRA    0.103096
# GBR   -0.034005
# ITA    0.023378
# JPN    0.039073
# ...
# GBR   -0.079966
# ITA    0.023173
# JPN    0.036465
# USA    0.083731
# Name: 2016-02-17, dtype: float64
# country
# AUS   -0.096873
# CAN   -0.002261
# CHE    0.225358
# DEU    0.017586
# ESP    0.012856
# FRA    0.111366
# GBR   -0.159255
# ITA    0.027590
# JPN    0.021942
# USA    0.068909
# Name: 2016-02-18, dtype: float64
# country
# AUS   -0.092737
# CAN   -0.029853
# CHE    0.195842
# DEU    0.021320
# ESP    0.019492
# FRA    0.136834
# GBR   -0.150733
# ITA    0.027140
# JPN    0.012632
# USA    0.063319
# Name: 2016-02-19, dtype: float64
# country
# AUS   -0.091369
# CAN   -0.008503
# CHE    0.193598
# DEU    0.023424
# ESP    0.017386
# FRA    0.139176
# GBR   -0.142981
# ITA    0.026276
# JPN   -0.001614
# USA    0.063267
# Name: 2016-02-22, dtype: float64
# country
# AUS   -0.106476
# CAN   -0.003257
# CHE    0.183910
# DEU    0.022810
# ESP    0.021057
# FRA    0.132382
# GBR   -0.154013
# ITA    0.028973
# JPN   -0.017562
# USA    0.064432
# Name: 2016-02-23, dtype: float64
# country
# AUS   -0.101672
# CAN   -0.000877
# CHE    0.137063
# DEU    0.025668
# ESP    0.028062
# FRA    0.159658
# GBR   -0.217527
# ITA    0.030350
# JPN   -0.032088
# USA    0.050963
# Name: 2016-02-24, dtype: float64
# country
# AUS   -0.127496
# CAN   -0.048535
# CHE    0.120478
# DEU    0.021443
# ESP    0.023400
# FRA    0.135437
# GBR   -0.169244
# ITA    0.021383
# JPN   -0.046091
# USA    0.075160
# Name: 2016-02-25, dtype: float64
# country
# AUS   -0.131950
# CAN   -0.050943
# CHE    0.113911
# DEU    0.018948
# ESP    0.020765
# FRA    0.118802
# GBR   -0.196414
# ITA    0.018831
# JPN   -0.065787
# USA    0.070493
# Name: 2016-02-26, dtype: float64
# country
# AUS   -0.132048
# CAN   -0.034939
# CHE    0.094444
# DEU    0.020310
# ESP    0.022699
# FRA    0.130649
# GBR   -0.227589
# ITA    0.022638
# JPN   -0.069346
# USA    0.064464
# Name: 2016-02-29, dtype: float64
# country
# AUS   -0.161478
# CAN   -0.003014
# CHE    0.104290
# DEU    0.018104
# ESP    0.021896
# FRA    0.112015
# GBR   -0.194729
# ITA    0.015729
# JPN   -0.126150
# USA    0.048968
# Name: 2016-03-01, dtype: float64
# country
# AUS   -0.128925
# CAN   -0.016975
# CHE    0.107715
# DEU    0.009271
# ESP    0.059634
# FRA    0.051535
# GBR   -0.136341
# ITA    0.037037
# JPN   -0.167022
# USA    0.047656
# Name: 2016-03-02, dtype: float64
# country
# AUS   -0.068961
# CAN   -0.051776
# CHE    0.098920
# DEU    0.019353
# ESP    0.016998
# FRA    0.094155
# GBR   -0.253483
# ITA    0.003239
# JPN   -0.122937
# USA    0.052064
# Name: 2016-03-03, dtype: float64
# country
# AUS   -0.091738
# CAN   -0.027969
# CHE    0.135055
# DEU    0.008845
# ESP    0.013402
# FRA    0.083326
# GBR   -0.209224
# ITA    0.030250
# JPN   -0.192724
# USA    0.018864
# Name: 2016-03-04, dtype: float64
# country
# AUS   -0.009461
# CAN   -0.152304
# CHE    0.026046
# DEU    0.002880
# ESP    0.088872
# FRA    0.009943
# GBR   -0.099485
# ITA    0.043779
# JPN   -0.284677
# USA    0.044557
# Name: 2016-03-07, dtype: float64
# country
# AUS   -0.200460
# CAN   -0.130589
# CHE    0.010168
# DEU    0.000670
# ESP    0.143076
# FRA    0.019194
# GBR   -0.036462
# ITA    0.059920
# JPN   -0.224999
# USA    0.021998
# Name: 2016-03-08, dtype: float64
# country
# AUS   -0.140758
# CAN   -0.114589
# CHE    0.002186
# DEU    0.010561
# ESP    0.091190
# FRA    0.133521
# GBR   -0.198888
# ITA    0.056323
# JPN   -0.059660
# USA    0.057291
# Name: 2016-03-09, dtype: float64
# country
# AUS   -0.126234
# CAN   -0.084033
# CHE    0.014178
# DEU    0.012213
# ESP    0.092977
# FRA    0.151036
# GBR   -0.220362
# ITA    0.059342
# JPN   -0.014048
# USA    0.068778
# Name: 2016-03-10, dtype: float64
# country
# AUS   -0.146697
# CAN   -0.070664
# CHE    0.010552
# DEU    0.005536
# ESP    0.127886
# FRA    0.104288
# GBR   -0.210740
# ITA    0.070411
# JPN   -0.034176
# USA    0.074751
# Name: 2016-03-11, dtype: float64
# country
# AUS   -0.138809
# CAN   -0.067069
# CHE    0.001622
# DEU    0.004156
# ESP    0.119874
# FRA    0.077727
# GBR   -0.209670
# ITA    0.055054
# JPN   -0.072187
# USA    0.102112
# Name: 2016-03-14, dtype: float64
# country
# AUS   -0.140315
# CAN   -0.058498
# CHE    0.009649
# DEU    0.001618
# ESP    0.125555
# FRA    0.064846
# GBR   -0.201386
# ITA    0.068303
# JPN   -0.034149
# USA    0.108472
# Name: 2016-03-15, dtype: float64
# country
# AUS   -0.145198
# CAN   -0.056149
# CHE    0.004321
# DEU    0.000591
# ESP    0.105047
# FRA    0.023528
# GBR   -0.148961
# ITA    0.043041
# JPN   -0.121226
# USA    0.146603
# Name: 2016-03-16, dtype: float64
# country
# AUS   -0.112525
# CAN   -0.044301
# CHE    0.004631
# DEU    0.000031
# ESP    0.072782
# FRA    0.060363
# GBR   -0.204098
# ITA    0.037766
# JPN   -0.060379
# USA    0.167614
# Name: 2016-03-17, dtype: float64
# country
# AUS   -0.104279
# CAN   -0.029094
# CHE    0.001682
# DEU   -0.001158
# ESP    0.093074
# FRA    0.089917
# GBR   -0.202927
# ITA    0.044637
# JPN   -0.043499
# USA    0.166386
# Name: 2016-03-18, dtype: float64
# country
# AUS   -0.087481
# CAN   -0.019930
# CHE    0.000200
# DEU   -0.002059
# ESP    0.070078
# FRA    0.061394
# GBR   -0.200085
# ITA    0.030828
# JPN   -0.059364
# USA    0.221939
# Name: 2016-03-21, dtype: float64
# country
# AUS   -0.112647
# CAN   -0.008080
# CHE    0.002864
# DEU   -0.003328
# ESP    0.044529
# FRA    0.050404
# GBR   -0.187013
# ITA    0.014449
# JPN   -0.013248
# USA    0.253428
# Name: 2016-03-22, dtype: float64
# country
# AUS   -0.123419
# CAN   -0.004563
# CHE    0.005180
# DEU   -0.004195
# ESP    0.044376
# FRA    0.068663
# GBR   -0.232371
# ITA    0.014629
# JPN   -0.027574
# USA    0.191875
# Name: 2016-03-23, dtype: float64
# country
# AUS   -0.128859
# CAN   -0.002122
# CHE    0.003426
# DEU   -0.003621
# ESP    0.022452
# FRA    0.007153
# GBR   -0.171847
# ITA    0.009717
# JPN   -0.057991
# USA    0.286852
# Name: 2016-03-24, dtype: float64
# country
# AUS   -0.138660
# CAN    0.000126
# CHE    0.003307
# DEU   -0.003371
# ESP    0.009851
# FRA    0.023156
# GBR   -0.154942
# ITA    0.026456
# JPN   -0.018462
# USA    0.320317
# Name: 2016-03-25, dtype: float64
# country
# AUS   -0.106244
# CAN    0.001254
# CHE    0.002740
# DEU   -0.004618
# ESP    0.004077
# FRA    0.001274
# GBR   -0.226326
# ITA    0.013830
# JPN   -0.049490
# USA    0.315609
# Name: 2016-03-28, dtype: float64
# country
# AUS   -0.117436
# CAN    0.001757
# CHE    0.000022
# DEU   -0.001737
# ESP    0.039684
# FRA    0.082316
# GBR   -0.163166
# ITA    0.039146
# JPN   -0.069201
# USA    0.301067
# Name: 2016-03-29, dtype: float64
# country
# AUS   -0.046193
# CAN    0.005205
# CHE   -0.000233
# DEU   -0.002227
# ESP    0.068446
# FRA    0.029470
# GBR   -0.244508
# ITA    0.027075
# JPN   -0.091039
# USA    0.358625
# Name: 2016-03-30, dtype: float64
# country
# AUS   -0.033903
# CAN    0.015995
# CHE   -0.000339
# DEU   -0.002975
# ESP    0.054048
# FRA    0.021545
# GBR   -0.219871
# ITA    0.025336
# JPN   -0.063522
# USA    0.341760
# Name: 2016-03-31, dtype: float64
# country
# AUS   -0.022008
# CAN    0.022354
# CHE   -0.001456
# DEU   -0.000346
# ESP    0.088564
# FRA    0.084901
# GBR   -0.116081
# ITA    0.027900
# JPN   -0.166135
# USA    0.284102
# Name: 2016-04-01, dtype: float64
# country
# AUS   -0.006924
# CAN    0.020620
# CHE   -0.004312
# DEU   -0.000936
# ESP    0.080210
# FRA    0.034022
# GBR   -0.149480
# ITA    0.015975
# JPN   -0.171124
# USA    0.358117
# Name: 2016-04-04, dtype: float64
# country
# AUS   -0.010558
# CAN    0.021189
# CHE   -0.007416
# DEU   -0.000807
# ESP    0.076383
# FRA    0.088356
# GBR   -0.142475
# ITA    0.008563
# JPN   -0.058847
# USA    0.319500
# Name: 2016-04-05, dtype: float64
# country
# AUS   -0.034236
# CAN    0.000582
# CHE   -0.014333
# DEU   -0.004890
# ESP    0.068509
# FRA    0.145982
# GBR   -0.021864
# ITA    0.002470
# JPN   -0.121001
# USA    0.183402
# Name: 2016-04-06, dtype: float64
# country
# AUS   -0.045934
# CAN    0.016204
# CHE   -0.011398
# DEU   -0.005130
# ESP    0.065579
# FRA    0.141899
# GBR   -0.021474
# ITA   -0.002170
# JPN   -0.210926
# USA    0.007482
# Name: 2016-04-07, dtype: float64
# country
# AUS   -0.052241
# CAN    0.020800
# CHE   -0.009296
# DEU   -0.003180
# ESP    0.057633
# FRA    0.103471
# GBR   -0.052120
# ITA   -0.005710
# JPN   -0.210167
# USA    0.072353
# Name: 2016-04-08, dtype: float64
# country
# AUS   -0.073161
# CAN    0.022862
# CHE   -0.007877
# DEU   -0.002849
# ESP    0.051525
# FRA    0.092050
# GBR   -0.071926
# ITA   -0.005465
# JPN   -0.152938
# USA    0.082407
# Name: 2016-04-11, dtype: float64
# country
# AUS   -0.074504
# CAN    0.007125
# CHE   -0.007635
# DEU   -0.000903
# ESP    0.058829
# FRA    0.100189
# GBR   -0.042419
# ITA   -0.015562
# JPN   -0.184771
# USA    0.013207
# Name: 2016-04-12, dtype: float64
# country
# AUS   -0.039469
# CAN    0.009612
# CHE   -0.004222
# DEU   -0.001161
# ESP    0.081393
# FRA    0.089847
# GBR   -0.041608
# ITA   -0.026442
# JPN   -0.010496
# USA    0.013577
# Name: 2016-04-13, dtype: float64
# country
# AUS   -0.029328
# CAN    0.080001
# CHE   -0.003183
# DEU   -0.000018
# ESP    0.060681
# FRA    0.036879
# GBR   -0.054848
# ITA   -0.014322
# JPN   -0.090213
# USA    0.197145
# Name: 2016-04-14, dtype: float64
# country
# AUS   -0.001788
# CAN    0.069506
# CHE   -0.003093
# DEU    0.000413
# ESP    0.051187
# FRA    0.061527
# GBR   -0.032954
# ITA   -0.026260
# JPN   -0.033480
# USA    0.116391
# Name: 2016-04-15, dtype: float64
# country
# AUS   -0.003157
# CAN    0.048933
# CHE    0.001858
# DEU    0.008641
# ESP    0.024828
# FRA    0.020120
# GBR   -0.054920
# ITA   -0.021074
# JPN   -0.099852
# USA    0.039645
# Name: 2016-04-18, dtype: float64
# country
# AUS   -0.028365
# CAN    0.029059
# CHE    0.010852
# DEU    0.016710
# ESP    0.008698
# FRA    0.076069
# GBR   -0.084143
# ITA   -0.014466
# JPN   -0.042815
# USA    0.086207
# Name: 2016-04-19, dtype: float64
# country
# AUS   -0.037050
# CAN    0.001788
# CHE    0.015511
# DEU    0.033146
# ESP    0.002492
# FRA    0.121754
# GBR   -0.087652
# ITA   -0.002452
# JPN   -0.157340
# USA    0.064433
# Name: 2016-04-20, dtype: float64
# country
# AUS   -0.064396
# CAN    0.010004
# CHE    0.016590
# DEU    0.033332
# ESP    0.003665
# FRA    0.097979
# GBR   -0.050900
# ITA   -0.019496
# JPN   -0.049979
# USA    0.135143
# Name: 2016-04-21, dtype: float64
# country
# AUS   -0.028284
# CAN    0.014289
# CHE    0.016597
# DEU    0.054325
# ESP    0.006224
# FRA    0.127737
# GBR   -0.047586
# ITA   -0.023299
# JPN   -0.033460
# USA    0.008308
# Name: 2016-04-22, dtype: float64
# country
# AUS   -0.021891
# CAN    0.018081
# CHE    0.021879
# DEU    0.063816
# ESP    0.004247
# FRA    0.135631
# GBR   -0.018576
# ITA   -0.016853
# JPN   -0.147578
# USA    0.043783
# Name: 2016-04-25, dtype: float64
# country
# AUS   -0.018915
# CAN    0.022223
# CHE    0.022882
# DEU    0.056797
# ESP    0.007455
# FRA    0.109569
# GBR   -0.045861
# ITA   -0.020561
# JPN   -0.009076
# USA    0.144487
# Name: 2016-04-26, dtype: float64
# country
# AUS   -0.004147
# CAN    0.002186
# CHE    0.024511
# DEU    0.072664
# ESP    0.012883
# FRA    0.131127
# GBR   -0.027126
# ITA   -0.020341
# JPN   -0.149321
# USA    0.168423
# Name: 2016-04-27, dtype: float64
# country
# AUS   -0.003803
# CAN    0.012929
# CHE    0.024093
# DEU    0.053867
# ESP    0.012539
# FRA    0.089151
# GBR   -0.038698
# ITA   -0.019527
# JPN   -0.187071
# USA    0.291593
# Name: 2016-04-28, dtype: float64
# country
# AUS   -0.037721
# CAN    0.002354
# CHE    0.036313
# DEU    0.048099
# ESP    0.011530
# FRA    0.074860
# GBR   -0.058951
# ITA   -0.023503
# JPN   -0.032959
# USA    0.308117
# Name: 2016-04-29, dtype: float64
# country
# AUS   -0.034400
# CAN    0.008220
# CHE    0.035079
# DEU    0.048700
# ESP    0.008238
# FRA    0.041430
# GBR   -0.080669
# ITA   -0.011755
# JPN   -0.156020
# USA    0.363920
# Name: 2016-05-02, dtype: float64
# country
# AUS   -0.077398
# CAN    0.013295
# CHE    0.013548
# DEU    0.017284
# ESP    0.002546
# FRA    0.048550
# GBR   -0.110392
# ITA   -0.008186
# JPN   -0.135814
# USA    0.362286
# Name: 2016-05-03, dtype: float64
# country
# AUS   -0.023613
# CAN    0.012810
# CHE    0.008265
# DEU    0.021481
# ESP    0.016075
# FRA    0.084063
# GBR   -0.144513
# ITA   -0.003082
# JPN   -0.032487
# USA    0.411029
# Name: 2016-05-04, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-176-f0580096033c> in <module>
#      16     training_eq = equity_ret.loc[start_date:end_date]
#      17     training_bond = bond_ret.loc[start_date:end_date]
# ---> 18     equities_risk_adj = training_eq/training_eq.std()
#      19     bond_risk_adj = training_bond/training_bond.std()
#      20     outperformance = equities_risk_adj - bond_risk_adj
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10974                                       skipna=skipna, ddof=ddof)
#   10975         return self._reduce(f, name, axis=axis, numeric_only=numeric_only,
# > 10976                             skipna=skipna, ddof=ddof)
#   10977
#   10978     return set_function_name(stat_func, name, cls)
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7405             try:
#    7406                 values = self.values
# -> 7407                 result = f(values)
#    7408
#    7409                 if (filter_type == 'bool' and is_object_dtype(values) and
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/frame.py in f(x)
#    7394
#    7395         def f(x):
# -> 7396             return op(x, axis=axis, skipna=skipna, **kwds)
#    7397
#    7398         # exclude timedelta/datetime unless we are uniform types
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     125                         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#     129                 try:
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in nanstd(values, axis, skipna, ddof, mask)
#     608     """
#     609     result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof,
# --> 610                             mask=mask))
#     611     return _wrap_results(result, values.dtype)
#     612
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     125                         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#     129                 try:
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#     645     dtype = values.dtype
#     646     if mask is None:
# --> 647         mask = isna(values)
#     648     if is_any_int_dtype(values):
#     649         values = values.astype('f8')
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#      97     Name: 1, dtype: bool
#      98     """
# ---> 99     return _isna(obj)
#     100
#     101
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     112                           ABCExtensionArray,
#     113                           ABCDatetimeArray, ABCTimedeltaArray)):
# --> 114         return _isna_ndarraylike(obj)
#     115     elif isinstance(obj, ABCGeneric):
#     116         return obj._constructor(obj._data.isna(func=isna))
#
# ~/.local/share/virtualenvs/Intership2020-RvVaDbFg/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     221
#     222     # box
# --> 223     if isinstance(obj, ABCSeries):
#     224         from pandas import Series
#     225         result = Series(result, index=obj.index, name=obj.name, copy=False)
#
# KeyboardInterrupt:

# %%
daily_ret.cumsum().plot()
plt.show()

# %%
daily_ret.std()
# Out:
# Returns    0.001496
# dtype: float64

# %%
0.001496/0.001204
# Out:
# 1.2425249169435215

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
    diffs = outperformance.diff().abs().loc[end_date]
    weights = diffs/diffs.sum()
    outperformance = outperformance.loc[end_date].multiply(weights)
    positions = (outperformance - outperformance.mean()) / outperformance.std()
#     global_mean = outperformance.loc[end_date].mean()
#     global_std = outperformance.loc[end_date].std()
#     positions = (outperformance.loc[end_date] - global_mean)/global_std
    
   
    #positions = positions.multiply(weights)
   # print(positions)
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
#     if daily_ret.loc[date].values < -.004:
#         print(positions)
#         print(outperformance.loc[end_date])
    
    end_date = date
daily_ret.plot()
plt.show()

# %%
daily_ret.cumsum().plot()
plt.show()

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
    global_mean = outperformance.loc[end_date].mean()
    global_std = outperformance.loc[end_date].std()
    positions = (outperformance.loc[end_date] - global_mean)/global_std
    
    diffs = outperformance.diff().abs().loc[end_date]
    weights = diffs/diffs.sum()
    positions = positions.multiply(weights)
    
    positions = (positions - positions.mean()) / positions.std()
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
#     if daily_ret.loc[date].values < -.004:
#         print(positions)
#         print(outperformance.loc[end_date])
    
    end_date = date
daily_ret.plot()
plt.show()

# %%
daily_ret.cumsum().plot()
plt.show()

# %%
start_date = '1990-01-01'
end_date = '2015-01-01'
trade_date = '2015-01-02'
unwind_date = '2019-01-01'
trade_range = pd.date_range(trade_date, unwind_date, freq='B')
daily_pl = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Daily P&L"])

equity_ret = equities.pct_change(WEEKDAYS_IN_YEAR)
bond_ret = BondReturnIdx.pct_change(WEEKDAYS_IN_YEAR)
one_day_returns = BondReturnIdx.pct_change(1)
daily_ret = pd.DataFrame(index = trade_range.to_period("B"), columns = ["Returns"])

#positions_track = pd.DataFrame(index = trade_range.to_period("B"), columns = equity_ret.columns)

for date in pd.date_range(trade_date, unwind_date, freq='B').date:
    training_eq = equity_ret.loc[start_date:end_date]
    training_bond = bond_ret.loc[start_date:end_date]
    equities_risk_adj = training_eq/training_eq.std()
    bond_risk_adj = training_bond/training_bond.std()
    outperformance = equities_risk_adj - bond_risk_adj
    outperformance = outperformance.rolling(20).mean()
    global_mean = outperformance.loc[end_date].mean()
    global_std = outperformance.loc[end_date].std()
    positions = (outperformance.loc[end_date] - global_mean)/global_std
    
    diffs = outperformance.diff().abs().loc[end_date]
    weights = diffs/diffs.sum()
    positions = positions.multiply(weights)
    min_val = positions.min()
    max_val = positions.max()
    positions = positions.apply(lambda x: (2 * (x - min_val) / (max_val - min_val)) - 1)
    daily_ret.loc[date] = positions.dot(one_day_returns.loc[date]) / positions.abs().sum()
    
#     if daily_ret.loc[date].values < -.004:
#         print(positions)
#         print(outperformance.loc[end_date])
    
    end_date = date
daily_ret.plot()
plt.show()

# %%
daily_ret.cumsum().plot()
plt.show()

# %%
daily_ret.std()
# Out:
# Returns    0.001577
# dtype: float64

# %%
annual_ret_r = pd.DataFrame(index=pd.date_range('2015-01-01', '2019-01-01', freq='A'), columns=["Annual Return"])
annual_ret_r
# Out:
#            Annual Return
# 2015-12-31           NaN
# 2016-12-31           NaN
# 2017-12-31           NaN
# 2018-12-31           NaN

# %%
for date in pd.date_range('2015-01-02', '2018-12-31', freq='B').date:
    print(daily_ret.loc[date].values[0])
    annual_ret_r.loc[str(date.year) + '-12-31'] += daily_ret.loc[date].values[0]

# %%
annual_ret_r.loc['2015-12-31'] = daily_ret.loc['2015-10-10'].values[0]

# %%
annual_ret_r.head()
# Out:
#            Annual Return
# 2015-12-31           NaN
# 2016-12-31           NaN
# 2017-12-31           NaN
# 2018-12-31           NaN

# %%
type(daily_ret.loc['2015-10-10'].values[0])
# Out:
# float
